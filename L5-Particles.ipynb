# %% [markdown]
# # Stochastic, interacting particles in time and space
#
# *** Dr Magnus Richardson (Mathematics Institute)***
# *** IATL Computer Modelling Module, 5th February 2018***
#
#
# *** Aim: ***  Computer simulations are a powerful tool for modelling the real world. They are particlarly useful for modelling stochastic, interacting agents that move through space: these systems are very hard to treat mathematically. The goal of this lecture is to introduce stochastic, spatial simulations using diffusing and reacting particles as an example. The material covers many of the basics used for more complex simulational models in biology, chemistry, physics or sociophysics.
#
# ** Example videos of stochastic interacting agents:**
#
# Bees
#
# https://www.youtube.com/watch?v=GmsrWJU1si8
#
# Lotka-Voltera stochastic simulations
#
# https://www.youtube.com/watch?v=UsYNGSUIS6o
#
# Simulated crowds in a stadium
#
# https://www.youtube.com/watch?v=97QIFsVqeh4
#
#
# More simulated crowds
#
# https://www.youtube.com/watch?v=daysCqmqd2Y
#
# ---
#
# **Section 1.** Sums of random numbers
# * **1.1** Gaussian or normal random numbers
# * **1.2** Gaussian random numbers with any mean and variance
# * **1.3** Sums of Gaussian random numbers
# * **1.4** Sums of other random numbers: binary example
# * **1.5** Summary points
#
# ** Section 2. ** Diffusion
# * **2.1** Simulating diffusion in one dimension
# * **2.2** Discrete space versus continuous space
# * **2.3** Diffusion in two dimensions
# * **2.4** Particle versus landscapce simulations
# * **2.5** Summary points
#
# ** Section 3. ** Interacting particles
# * **3.1** Diffusion-death process in 1D
# * **3.2** Simple reaction-diffusion process in 1D
# * **3.3** Two-species reaction-diffusion process in 1D
# * **3.4** Simple reaction-diffusion process in 2D
# * **3.5** Summary points

# %%
# load up the plotting functions
using Plots
gr();

# %% [markdown]
# # Section 1. Sums of random numbers
#
# * **1.1** Gaussian or normal random numbers
# * **1.2** Gaussian random numbers with any mean and variance
# * **1.3** Sums of Gaussian random numbers
# * **1.4** Sums of other random numbers: binary example
# * **1.5** Summary points

# %% [markdown]
# ---

# %% [markdown]
# ## 1.1 Gaussian or normal random numbers
#
# Standard normal random numbers have the property
#
# * A mean of zero so that $\langle\phi\rangle$=0
#
# * A variance of one so that Var=$\langle\phi^2\rangle$-$\langle\phi\rangle^2=1$
#
# * The probability density for normal random numbers is the Gaussian
#
# $$ p(\phi)=\frac{1}{\sqrt{2\pi}}\exp(-\phi^2/2) $$
#
# * Can be generated by the command randn()

# %%
# generate the random numbers
nsamples=1000
phi=randn(nsamples)

# theory
xx=collect(-5:0.01:5)
yy=exp.(-xx.^2/2)/sqrt(2*pi)

# plot out data
histogram(phi,normed=true,bins=20,label="samples")
plot!(xx,yy,color=[:black], label="theory")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0702">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   169.245,375.813 169.245,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   306.269,375.813 306.269,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   443.292,375.813 443.292,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,291.162 580.315,291.162
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,206.51 580.315,206.51
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,121.858 580.315,121.858
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,37.2065 580.315,37.2065
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   169.245,375.813 169.245,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   306.269,375.813 306.269,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   443.292,375.813 443.292,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 40.4435,375.813
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,291.162 40.4435,291.162
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,206.51 40.4435,206.51
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,121.858 40.4435,121.858
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,37.2065 40.4435,37.2065
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 389.613)" x="32.2221" y="389.613">-5.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 169.245, 389.613)" x="169.245" y="389.613">-2.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 306.269, 389.613)" x="306.269" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 443.292, 389.613)" x="443.292" y="389.613">2.5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">5.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 380.313)" x="26.2221" y="380.313">0.0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 295.662)" x="26.2221" y="295.662">0.1</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 211.01)" x="26.2221" y="211.01">0.2</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 126.358)" x="26.2221" y="126.358">0.3</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 41.7065)" x="26.2221" y="41.7065">0.4</text>
# </g>
# <polygon clip-path="url(#clip0702)" points="
# 141.841,369.041 141.841,375.813 169.245,375.813 169.245,369.041 141.841,369.041 141.841,369.041
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.841,369.041 141.841,375.813 169.245,375.813 169.245,369.041 141.841,369.041
#   "/>
# <polygon clip-path="url(#clip0702)" points="
# 169.245,343.646 169.245,375.813 196.65,375.813 196.65,343.646 169.245,343.646 169.245,343.646
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   169.245,343.646 169.245,375.813 196.65,375.813 196.65,343.646 169.245,343.646
#   "/>
# <polygon clip-path="url(#clip0702)" points="
# 196.65,286.083 196.65,375.813 224.055,375.813 224.055,286.083 196.65,286.083 196.65,286.083
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.65,286.083 196.65,375.813 224.055,375.813 224.055,286.083 196.65,286.083
#   "/>
# <polygon clip-path="url(#clip0702)" points="
# 224.055,242.064 224.055,375.813 251.459,375.813 251.459,242.064 224.055,242.064 224.055,242.064
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:1

# %% [markdown]
# ---

# %% [markdown]
# ## 1.2 Gaussian numbers with any mean and variance
#
# Non-standard normals may have a non-zero mean and a variance that is different from unity.
#
# $x=\mu+\sigma\phi$
#
# So that $\langle x\rangle=\mu+\sigma\langle \phi\rangle=\mu$
#
# and
#
# Var$(x)=\langle x^2\rangle-\langle x\rangle^2=\langle\left(\mu+\sigma\phi\right)^2\rangle-\mu^2=2\sigma\mu\langle\phi\rangle+\sigma^2\langle\phi^2\rangle$
#
# so
#
# Var$(x)=\sigma^2$
#
# These can be straightforwardly generated numerically and have the distribution
#
#
#  $$ p(x)=\frac{1}{\sqrt{2\pi\sigma^2}}\exp(-(x-\mu)^2/2\sigma^2) $$

# %%
# parameters
m=5.0 # mean
s=2.0 # standard deviation (square root of variance)

# generate the random numbers
nsamples=1000
x=m + s*randn(nsamples)

# theoretical distribution
# define an inline function that generates general Gaussian distributions
g(xx,m,s)=exp.(-(xx-m).^2/(2s^2))/sqrt(2*pi*s^2)
xx=collect(-3:0.01:13)
yy=g(xx,m,s)

# some plots
histogram(x,normed=true,bins=20,label="samples")
plot!(xx,yy,color=[:black],label="theory")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 38.8117,375.813 580.315,375.813 580.315,11.811 38.8117,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0902">
#     <rect x="38" y="11" width="543" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   71.7299,375.813 71.7299,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.566,375.813 137.566,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   203.402,375.813 203.402,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   269.239,375.813 269.239,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   335.075,375.813 335.075,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   400.911,375.813 400.911,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   466.747,375.813 466.747,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   532.584,375.813 532.584,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,290.367 580.315,290.367
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,204.92 580.315,204.92
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,119.474 580.315,119.474
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,34.0271 580.315,34.0271
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 38.8117,11.811
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   71.7299,375.813 71.7299,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.566,375.813 137.566,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   203.402,375.813 203.402,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.239,375.813 269.239,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   335.075,375.813 335.075,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   400.911,375.813 400.911,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   466.747,375.813 466.747,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   532.584,375.813 532.584,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 46.9343,375.813
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,290.367 46.9343,290.367
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,204.92 46.9343,204.92
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,119.474 46.9343,119.474
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,34.0271 46.9343,34.0271
#   "/>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 71.7299, 389.613)" x="71.7299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.566, 389.613)" x="137.566" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 203.402, 389.613)" x="203.402" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.239, 389.613)" x="269.239" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 335.075, 389.613)" x="335.075" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 400.911, 389.613)" x="400.911" y="389.613">8</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 466.747, 389.613)" x="466.747" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 532.584, 389.613)" x="532.584" y="389.613">12</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 380.313)" x="32.8117" y="380.313">0.00</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 294.867)" x="32.8117" y="294.867">0.05</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 209.42)" x="32.8117" y="209.42">0.10</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 123.974)" x="32.8117" y=

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3 Sums of Gaussian random numbers
#
# Sum of Gaussians is still a Gaussian.
#
# Let $x=\mu+\sigma\phi$
#
# $x_3=x_1+x_2$
#
# so that
#
# $x_3=\mu_1+\mu_2+\sigma_1\phi_1+\sigma_2\phi_2$
#
# Hence the mean is $\mu_3=\mu_1+\mu_2$ and variance is $\sigma_3^2=\sigma_1^2+\sigma_2^2$
#
# Note that this means the sum of $N$ identical Gaussians is $N\mu$ and the variance is $N\sigma^2$.

# %%
# parameters for the data
m1,s1=-4.0,1.0 # first type of random number 
m2,s2=4.0,1.0  # second type of random number

# generate the samples
nsamples=1000
x1=m1+s1*randn(nsamples)
x2=m2+s2*randn(nsamples)

# the theory
m3=m1+m2 # mean for the sum 
s3=sqrt(s1^2+s2^2) # standard deviation for the sum

xx=collect(-20:0.01:20)
yy1=g(xx,m1,s1)
yy2=g(xx,m2,s2)
yy3=g(xx,m3,s3)

# some plots
histogram(x1+x2,normed=true,bins=20,label="sum of samples")
plot!(xx,yy1,label="theory for # 1")
plot!(xx,yy2,label="theory for # 2")
plot!(xx,yy3,label="theory for their sum",color=[:black])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1102">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   169.245,375.813 169.245,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   306.269,375.813 306.269,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   443.292,375.813 443.292,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,284.572 580.315,284.572
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,193.33 580.315,193.33
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,102.088 580.315,102.088
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   169.245,375.813 169.245,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   306.269,375.813 306.269,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   443.292,375.813 443.292,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 40.4435,375.813
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,284.572 40.4435,284.572
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,193.33 40.4435,193.33
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,102.088 40.4435,102.088
#   "/>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 389.613)" x="32.2221" y="389.613">-20</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 169.245, 389.613)" x="169.245" y="389.613">-10</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 306.269, 389.613)" x="306.269" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 443.292, 389.613)" x="443.292" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 380.313)" x="26.2221" y="380.313">0.0</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 289.072)" x="26.2221" y="289.072">0.1</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 197.83)" x="26.2221" y="197.83">0.2</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 106.588)" x="26.2221" y="106.588">0.3</text>
# </g>
# <polygon clip-path="url(#clip1102)" points="
# 230.906,373.989 230.906,375.813 237.757,375.813 237.757,373.989 230.906,373.989 230.906,373.989
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   230.906,373.989 230.906,375.813 237.757,375.813 237.757,373.989 230.906,373.989
#   "/>
# <polygon clip-path="url(#clip1102)" points="
# 237.757,372.164 237.757,375.813 244.608,375.813 244.608,372.164 237.757,372.164 237.757,372.164
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   237.757,372.164 237.757,375.813 244.608,375.813 244.608,372.164 237.757,372.164
#   "/>
# <polygon clip-path="url(#clip1102)" points="
# 244.608,373.989 244.608,375.813 251.459,375.813 251.459,373.989 244.608,373.989 244.608,373.989
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   244.608,373.989 244.608,375.813 251.459,375.813 251.459,373.989 244.608,373.989
#   "/>
# <polygon clip-path="url(#clip1102)" points="
# 251.459,368.514 251.459,375.813 258.31,375.813 258.31,368.514 251.459,368.514 251.459,368.514
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   251.459,368.514 251.459,375.813 258.31,375.813 258.31,368.514 251.459,368.514
#   "/>
# <polygon clip-path="url(#clip1102)" points="
# 258.31,368.514 258.31,375.813 265.162,375.813 265.162,368.514 258.31,368.514 258.31,368.514
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   258.31,368.514 258.31,375.813 265.162,375.813 265.162,368.514 258.31,368.514
#   "/>
# <polygon clip-path="url(#clip1102)" points="
# 265.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.4 Sums of other random variables: binary example
#
# If you add many random variables together, regardless of their distribution, they tend towards a Gaussian.
#
# Imagine $x$ has mean and variance $\mu$ and $\sigma^2$. A sum of $N$ of these
#
# $X_N=\sum_{k=1}^Nx_k$
#
# has mean $N\mu$ and variance $N\sigma^2$. Hence, we expect it to be well approximated by
#
#  $$ p(X)=\frac{1}{\sqrt{2\pi N\sigma^2}}\exp(-(X-N\mu)^2/2N\sigma^2) $$
#
# ---
#
# ** Example using binary random numbers **
#
# Consider a random number x where
#
# $x=1$ with probability $p$
# $x=0$ with probability $1-p$
#
# Mean of $x$ is $\mu=\langle x \rangle=(1\times p)+(0\times(1-p))=p$
#
# Variance of $x$ is Var$(x)=\sigma^2=\langle x^2 \rangle - \langle x \rangle^2=\langle x \rangle - \langle x \rangle^2=p(1-p)$
#
# So a sum $X$ of $N$ of these numbers has mean $Np$ and Variance $Np(1-p)$.
#
# We can now compare sums of $N$ of these numbers,
# with different values of $N$, with a Gaussian that has the same mean and variance.

# %%
############################
# parameters
############################

p=0.3 # probability of a 1 for the binary random numbers

# Quantity of random numbers to sum
N1=1    
N2=10  
N3=100
 
############################
# collect some samples
############################

# inline function for the sum of binary random numbers
XN(N,p)=Int(sum(rand(N).<p))

nsamples=10000
X1=zeros(nsamples)
X2=zeros(nsamples)
X3=zeros(nsamples)

for k=1:nsamples
    X1[k]=XN(N1,p)
    X2[k]=XN(N2,p)
    X3[k]=XN(N3,p)
end
    
############################
#  theory
############################

# calculate mean and standard deviations for X1 and X2
m1,s1=p*N1,sqrt(p*(1-p)*N1)
m2,s2=p*N2,sqrt(p*(1-p)*N2)
m3,s3=p*N3,sqrt(p*(1-p)*N3)

# equivalent Gaussians with same mean and variance
xx=collect(-5:0.1:100)
yy1=g(xx,m1,s1)
yy2=g(xx,m2,s2)
yy3=g(xx,m3,s3)

############################
# plot out the results
############################

p1=histogram(X1,normed=true,bins=10)
p1=plot!(xx,yy1,xlim=(m1-5*s1,m1+5*s1),title="Binary numbers summed: N=$N1",legend=false)

p2=histogram(X2,normed=true,bins=10)
p2=plot!(xx,yy2,xlim=(m2-5*s2,m2+5*s2),title="Binary numbers summed: N=$N2",legend=false)

p3=histogram(X3,normed=true,bins=20)
p3=plot!(xx,yy3,xlim=(m3-5*s3,m3+5*s3),title="Binary numbers summed: N=$N3",legend=false)

plot(p1,p2,p3)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1300)" points="
# 38.8117,175.813 280.315,175.813 280.315,31.4961 38.8117,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1302">
#     <rect x="38" y="31" width="243" height="145"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   91.0529,175.813 91.0529,31.4961
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   143.753,175.813 143.753,31.4961
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   196.454,175.813 196.454,31.4961
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   249.154,175.813 249.154,31.4961
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,175.813 280.315,175.813
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,155.093 280.315,155.093
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,134.373 280.315,134.373
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,113.652 280.315,113.652
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,92.932 280.315,92.932
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,72.2116 280.315,72.2116
#   "/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,51.4912 280.315,51.4912
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,175.813 280.315,175.813
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,175.813 38.8117,31.4961
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.0529,175.813 91.0529,173.649
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   143.753,175.813 143.753,173.649
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.454,175.813 196.454,173.649
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   249.154,175.813 249.154,173.649
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,175.813 42.4343,175.813
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,155.093 42.4343,155.093
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,134.373 42.4343,134.373
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,113.652 42.4343,113.652
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,92.932 42.4343,92.932
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,72.2116 42.4343,72.2116
#   "/>
# <polyline clip-path="url(#clip1300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,51.4912 42.4343,51.4912
#   "/>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 91.0529, 189.613)" x="91.0529" y="189.613">-1</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 143.753, 189.613)" x="143.753" y="189.613">0</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 196.454, 189.613)" x="196.454" y="189.613">1</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 249.154, 189.613)" x="249.154" y="189.613">2</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 180.313)" x="32.8117" y="180.313">0</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 159.593)" x="32.8117" y="159.593">1</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 138.873)" x="32.8117" y="138.873">2</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 118.152)" x="32.8117" y="118.152">3</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 97.432)" x="32.8117" y="97.432">4</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 76.7116)" x="32.8117" y="76.7116">5</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 55.9912)" x="32.8117" y="55.9912">6</text>
# </g>
# <g clip-path="url(#clip1300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 159.563, 18)" x="159.563" y="18">Binary numbers summed: N=1</text>
# </g>
# <polygon clip-path="url(#clip1302)" points="
# 143.753,31.4961 143.753,175.813 149.023,175.813 149.023,31.4961 143.753,31.4961 143.753,31.4961
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   143.753,31.4961 143.753,175.813 149.023,175.813 149.023,31.4961 143.753,31.4961
#   "/>
# <polygon clip-path="url(#clip1302)" points="
# 149.023,175.813 149.023,175.813 154.293,175.813 154.293,175.813 149.023,175.813 149.023,175.813
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1302)

# %% [markdown]
# ---

# %% [markdown]
# ## 1.5 Summary points
#
# * Large sums $X$ of $N$ identical, independent random numbers $x_k$ can be well approximated by a Gaussian distribution.
#
#
# * In the context of diffusion, this means that whatever the form of the small hops, at large scales and long times the distribution of diffusing objects will have a Gaussian distribution.
#
#
#
# * The mean $\mu=\langle{x}\rangle$ and variance $\sigma^2=\langle x^2\rangle-\langle x\rangle^2$ of the random numbers that make up the sum can be used to calculate the mean and variance of $X$
#
#
#
# * So that $\langle X \rangle=N\langle x \rangle$ and Var$(X)=N$Var$(x)$.

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Section 2. Diffusion
#
# * **2.1** Simulating diffusion in one dimension
# * **2.2** Discrete space versus continuous space
# * **2.3** Diffusion in two dimensions
# * **2.4** Particle versus landscapce simulations
# * **2.5** Summary points

# %% [markdown]
# ---

# %% [markdown]
# ## 2.1 Simulating diffusion in one dimension
#
# Diffusion is the result of many random hops: $x=h_1+h_2+...h_k$
# which is just a sum of random numbers so we can use previous results.
#
# Parameterise a random walker, or diffusing particle by
# mean velocity $v$
# diffusion constant $D$
#
#
# To simulate the motion for a time $T$ we need to breakdown time into steps $dt$, with a hop each step
# Total number of hops is $T/dt$
#
# The statistics of the diffusion should not depend on the time step.
# Some care is needed so that results independent on $dt$.
#
# ** Setting up the problem correctly in time **
#
# After a time $T$ the particle will on average be at a position $vT$ with variance $2DT$.
#
# Let's assume that the microscopic hops are Gaussians with mean $\mu$ and variance $\sigma^2$
#
# After a time $T$ the mean position is $\mu T/dt$ and variance is $\sigma^2 T/dt$.
#
# Hence we need $\mu=v dt$ and $\sigma=\sqrt{2D dt}$.

# %%
############################
# parameters
############################

T=5.0 # total time
dt1=0.01 # one example time step
dt2=0.5  # another example time step

np=1000 # number of particles, equivalent to the samples previously

# parameters of the diffusion process
v=0.1 # velocity
D=0.2 # diffusion constant

# number of steps for the two examples
nt1=Int(T/dt1)
nt2=Int(T/dt2)

# time grids for the plots
t1=dt1*collect(1:nt1)
t2=dt2*collect(1:nt2)

# positions matrix for the np particles: column is time, rows are the particles
x1=zeros(nt1,np)
x2=zeros(nt2,np)

# here is the simulation evolving the system forward in time for example 1
for k=1:nt1-1
   x1[k+1,:]=x1[k,:] + v*dt1 + sqrt(2*D*dt1)*randn(np)
end

# and the same for example two
for k=1:nt2-1
   x2[k+1,:]=x2[k,:] + v*dt2 + sqrt(2*D*dt2)*randn(np) 
end

# %%
# plot out the data

p1=plot(t1,x1[:,1:5],xlabel="time",ylabel="position",legend=false,title="Five random walkers")
p2=plot(t2,x2[:,1:5],xlabel="time",ylabel="position",legend=false,title="Five random walkers")

p3=histogram(x1[end,:],normed=true,bins=50,title="At time $T for two examples")
p3=histogram!(x2[end,:],normed=true,bins=50,xlabel="position",legend=false)

plot(p1,p2,p3)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1500)" points="
# 45.0072,160.065 280.315,160.065 280.315,31.4961 45.0072,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1502">
#     <rect x="45" y="31" width="236" height="130"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   91.6915,160.065 91.6915,31.4961
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   138.847,160.065 138.847,31.4961
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   186.003,160.065 186.003,31.4961
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   233.159,160.065 233.159,31.4961
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   280.315,160.065 280.315,31.4961
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.0072,144.474 280.315,144.474
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.0072,111.225 280.315,111.225
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.0072,77.9764 280.315,77.9764
#   "/>
# <polyline clip-path="url(#clip1502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.0072,44.7278 280.315,44.7278
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,160.065 280.315,160.065
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,160.065 45.0072,31.4961
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.6915,160.065 91.6915,158.137
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   138.847,160.065 138.847,158.137
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   186.003,160.065 186.003,158.137
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   233.159,160.065 233.159,158.137
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   280.315,160.065 280.315,158.137
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,144.474 48.5368,144.474
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,111.225 48.5368,111.225
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,77.9764 48.5368,77.9764
#   "/>
# <polyline clip-path="url(#clip1500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,44.7278 48.5368,44.7278
#   "/>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 91.6915, 173.865)" x="91.6915" y="173.865">1</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 138.847, 173.865)" x="138.847" y="173.865">2</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 186.003, 173.865)" x="186.003" y="173.865">3</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 233.159, 173.865)" x="233.159" y="173.865">4</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 280.315, 173.865)" x="280.315" y="173.865">5</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 148.974)" x="39.0072" y="148.974">-1</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 115.725)" x="39.0072" y="115.725">0</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 82.4764)" x="39.0072" y="82.4764">1</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 49.2278)" x="39.0072" y="49.2278">2</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 162.661, 18)" x="162.661" y="18">Five random walkers</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 162.661, 197.6)" x="162.661" y="197.6">time</text>
# </g>
# <g clip-path="url(#clip1500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 95.7807)" x="14.4" y="95.7807">position</text>
# </g>
# <polyline clip-path="url(#clip1502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,111.225 45.4787,109.262 45.9503,107.696 46.4219,107.408 46.8934,108.664 47.365,107.119 47.8365,106.431 48.3081,106.556 48.7796,107.328 49.2512,107.191
#   49.7228,107.146 50.1943,105.561 50.6659,105.461 51.1374,102.855 51.609,101.346 52.0806,101.076 52.5521,104.109 53.0237,104.177 53.4952,101.612 53.9668,102.66
#   54.4383,100.589 54.9099,98.8535 55.3815,101.323 55.853,101.29 56.3246,101.975 56.7961,104.779 57.2677,102.539 57.7393,103.514 58.2108,106.965 58.6824,109.219
#   59.1539,110.852 59.6255,111.128 60.0971,109.081 60.5686,111.264 61.0402,112.502 61.5117,114.529 61.9833,118.823 62.4548,116.383 62.9264,117.995 63.398,119.872
#   63.8695,120.328 64.3411,118.922 64.8126,118.2 65.2842,119.768 65.7558,117.308 66.2273,120.212 66.6989,118.486 67.1704,120.828 67.642,119.717 68.1135,118.604
#   68.5851,116.392 69.0567,115.443 69.5282,112.996 69.9998,112.029 70.4713,110.06 70.9429,111.076 71.4145,112.493 71.886,115.471 72.3576,117.75 72.8291,115.365
#   73.3007,116.931 73.7723,117.723 74.2438,117.63 74.7154,115.977 75.1869,115.328 75.6585,113.211 76.13,110.469 76.6016,106.981 77.0732,1

# %% [markdown]
# ---

# %% [markdown]
# ## 2.2 Discrete space versus continuous space
#
# For many situations it is convenient to consider space as a grid of points
# so the walker is on a lattice on which it hops to neighbouring points.
#
# Consider a case where a walker hops forward with probability $p$ or stays still $1-p$ per time step.
# Note: this is like a sum of binary random numbers which we know converges to a Gaussian.
#
# After a time $T$ we still need the particle on average to be at position $vT$ with variance $2DT$.
# What value does $p$ need to take?
#
# In this case $\langle h \rangle=p$ and Var$(h)=\langle h^2\rangle-\langle h\rangle^2=p(1-p)$
#
# Hence $p=vdt$ and so because $p(1-p)=2Ddt$ we also have $D\sim v/2$.
# This links the allowable velocity $v$ and diffusion constant $D$ for this walker.
#
# The sum of binary numbers converges to a Gaussian distribution.
# We therefore expect that these walkers will have the distribution
#
# $$ p(X)=\frac{1}{\sqrt{2\pi vt}}\exp(-(X-vt)^2/2vt) $$

# %%
# parameters
v=5  # velocity of the walker
T=10 # time of the simlation

dt=0.01 # time step 
nt=Int(ceil(T/dt)) # number of time steps
t=dt*collect(1:nt) # times for the plots

p=dt*v # hop probability per time step

np=1000 # number of walkers
x=zeros(nt,np) # matrix of walkers: column is time rows are for each particle

# simulate the system
for k=1:nt-1
    x[k+1,:]=x[k,:] + 1.0(rand(np).<p)
end

# %%
# consider three time points
t1=2.5; s1=Int(t1/dt)
t2=5.0; s2=Int(t2/dt)
t3=10.0; s3=Int(t3/dt)

# the theory
xx=collect(0:0.1:80)
y1=g(xx,t1*v,sqrt(t1*v))
y2=g(xx,t2*v,sqrt(t2*v))
y3=g(xx,t3*v,sqrt(t3*v))

# plots

p1=plot(t,x[:,1:10],legend=false,title="Ten example paths",xlabel="time",ylabel="position")

p2=histogram(x[s1,:],normed=true,bins=20,label="time $t1")
p2=histogram!(x[s2,:],normed=true,bins=20,label="time $t2")
p2=histogram!(x[s3,:],normed=true,bins=20,label="time $t3")

p2=plot!(xx,y1,color=[:black],label="",xlabel="position",title="distributions")
p2=plot!(xx,y2,color=[:black],label="",title="distributions compared to gaussians")
p2=plot!(xx,y3,color=[:black],label="")

plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1700)" points="
# 44.6753,360.065 279.952,360.065 279.952,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1702">
#     <rect x="44" y="31" width="236" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   91.5422,360.065 91.5422,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   138.645,360.065 138.645,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   185.747,360.065 185.747,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   232.85,360.065 232.85,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   279.952,360.065 279.952,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,360.065 279.952,360.065
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,307.912 279.952,307.912
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,255.758 279.952,255.758
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,203.604 279.952,203.604
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,151.45 279.952,151.45
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,99.2961 279.952,99.2961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,47.1422 279.952,47.1422
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 279.952,360.065
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,31.4961
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.5422,360.065 91.5422,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   138.645,360.065 138.645,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   185.747,360.065 185.747,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   232.85,360.065 232.85,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   279.952,360.065 279.952,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 48.2045,360.065
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,307.912 48.2045,307.912
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,255.758 48.2045,255.758
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,203.604 48.2045,203.604
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,151.45 48.2045,151.45
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,99.2961 48.2045,99.2961
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,47.1422 48.2045,47.1422
#   "/>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 91.5422, 373.865)" x="91.5422" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 138.645, 373.865)" x="138.645" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 185.747, 373.865)" x="185.747" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 232.85, 373.865)" x="232.85" y="373.865">8</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 279.952, 373.865)" x="279.952" y="373.865">10</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 364.565)" x="38.6753" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 312.412)" x="38.6753" y="312.412">10</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 260.258)" x="38.6753" y="260.258">20</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 208.104)" x="38.6753" y="208.104">30</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 155.95)" x="38.6753" y="155.95">40</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 103.796)" x="38.6753" y="103.796">50</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 51.6422)" x="38.6753" y="51.6422">60</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 162.314, 18)" x="162.314" y="18">Ten example paths</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#0

# %% [markdown]
# ---

# %% [markdown]
# ## 2.3 Diffusion in two dimensions
#
# So far we have considered diffusion that is one dimension only.
#
# It is straightforward to generalise to 2D or 3D (or higher dimensions!)
#
# We assume that the random hops in the $x$ and $y$ direction are independent.
#
# For 2D the distribution of a walker with position $(x,y)$ we:
# allow for velocity components $v_x$ and $v_y$
# assume that the diffusion is isotropic
#
# In this case the distribution is simply the product of two gaussians
#
#  $$ p(x,y)=\frac{1}{(4\pi Dt)}\exp\left(-\frac{1}{4Dt}\left((x-v_xt)^2+(y-v_yt)^2\right)\right) $$
#
# Note that the factor in front of the exponential is now the square of that for 1D.
#
# The mean position $(x,y)$ at a time t is $(v_xt,v_yt)$
# The variance in the position $(x-v_xt)^2+(y-v_yt)^2=4Dt$ (Note: this is twice that for 1D)

# %%
# NB: this is a continuous-space simulation

# parameters

D=2.0 # diffusion constant

T=5.0 # duration
dt=0.01 # time step
nt=Int(T/dt) # number of steps 
t=dt*collect(1:nt) # time vector

np=1000 # number of particles

# the simulation

x=zeros(nt,np) # x position: column is time, rows are particles
y=zeros(nt,np) # y position

# evolve the system
for k=1:nt-1
    x[k+1,:]=x[k,:] + sqrt(2*D*dt)*randn(np)
    y[k+1,:]=y[k,:] + sqrt(2*D*dt)*randn(np)
end

# %%
# plot out np particles
np=20

for k=10:10:nt 
    p1 = plot(x[1:k,1:np],y[1:k,1:np],title="step $k. time=$(round(dt*k,1))",legend=false)
    p1 = scatter!(x[k,1:np],y[k,1:np],xlim=[-40,40],ylim=[-40,40])
    IJulia.clear_output(true)
    display(p1)
    sleep(0.2)
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1700)" points="
# 35.8488,375.813 580.315,375.813 580.315,31.4961 35.8488,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1702">
#     <rect x="35" y="31" width="545" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.2582,375.813 51.2582,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   179.67,375.813 179.67,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   308.082,375.813 308.082,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   436.494,375.813 436.494,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.906,375.813 564.906,31.4961
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,366.069 580.315,366.069
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,284.862 580.315,284.862
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,203.655 580.315,203.655
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,122.448 580.315,122.448
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,41.2409 580.315,41.2409
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,31.4961
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.2582,375.813 51.2582,370.649
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   179.67,375.813 179.67,370.649
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   308.082,375.813 308.082,370.649
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   436.494,375.813 436.494,370.649
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.906,375.813 564.906,370.649
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,366.069 44.0158,366.069
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,284.862 44.0158,284.862
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,203.655 44.0158,203.655
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,122.448 44.0158,122.448
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,41.2409 44.0158,41.2409
#   "/>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 51.2582, 389.613)" x="51.2582" y="389.613">-40</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 179.67, 389.613)" x="179.67" y="389.613">-20</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 308.082, 389.613)" x="308.082" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 436.494, 389.613)" x="436.494" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.906, 389.613)" x="564.906" y="389.613">40</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 370.569)" x="29.8488" y="370.569">-40</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 289.362)" x="29.8488" y="289.362">-20</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 208.155)" x="29.8488" y="208.155">0</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 126.948)" x="29.8488" y="126.948">20</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 45.7409)" x="29.8488" y="45.7409">40</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 308.082, 18)" x="308.082" y="18">step 500. time=5.0</text>
# </g>
# <polyline clip-path="url(#clip1702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   308.082,203.655 307.361,203.336 305.358,204.056 306.341,202.679 308.432,202.58 309.314,202.169 310.284,202.964 311.316,203.616 311.724,203.395 309.89,203.828
#   312.019,203.922 310.424,202.632 310.467,203.31 310.298,203.524 310.345,205.023 311.789,204.328 314.468,204.89 318.403,205.101 317.998,204.504 318.822,203.859
#   317.917,203.386 321.156,204.211 321.703,204.304 321.88,203.922 321.531,204.802 319.344,205.322 319.129,205.626 320.308,206.256 322.132,206.573 321.801,206.861
#   323.148,206.195 323.718,205.836 321.803,207.022 321.415,206.501 320.964,206.849 321.902,207.211 321.722,207.494 322.4,207.28 321.583,208.153 321.724,207.763
#   321.6,206.83 320.214,207.461 319.803,205.951 319.554,206.276 321.933,205.473 322.452,206.375 319.285,205.814 322.644,206.93 322.723,208.9 323.504,209.324
#   324.667,210.24 322.274,211.03 321.999,211.841 324.013,211.945 325.332,213.269 325.31,213.312 327.889,212.887 327.534,212.51 327.879,212.902 329.204,212.081
#   330.592,211.056 329.254,211.402 329.644,211.59 331.301,210.321 331.84

# %% [markdown]
# ---

# %% [markdown]
# ## 2.4 Particle versus landscape simulations
#
# The simulations so far have kept an array of particle positions and updated them.
#
# Another strategy is to keep an array or matrix of the environment and move particles around in it.
#
# This can be very useful when particles interact.
#
# ** Example: ** A particle on a 1D lattice with $L$ positions.
#
# The particle hops to left (prob $p$) or right (prob $p$) or stays still (prob $1-2p$).
# The mean hop is zero, the variance is $2p$ so setting $p=D dt$ gives the particle a diffusion constant of $D$.
# The particle is not allowed to hop off the lattice from site $1$ or $L$
#
# The state of the system is a 1D vector with $L$ entries.
# All entries are $0$ except the one where the particle is where it is $1$.
#
#
# The algorithm is:
#
# Initially: set all sites to $0$ except where the particles starts, which can be $1$
# Then for each time step repeat steps (1-3) L-1 times.
#
# (1) Pick a pair of adjacent sites at random (L-1 of these)
# (2) If the pair is 01 then with probability $p$ it flips to 10
# (3) If the pair is 10 then with probability $p$ it flips to 01

# %%
# parameters

D=5.0 # diffusion constant

dt,T=0.01,50.0 # various time quantities
nt=Int(T/dt)
t=dt*collect(1:nt)

p=D*dt # hop probability

L=200 # lattice size

S=zeros(nt,L)   # this is the lattice space in time: column=time, row=lattice entry
S[1,Int(L/2)]=1 # initialise with particle in the middle

for k=1:nt-1 # loop over time
    for j=1:L-1 # loop of L-1 pairs
        
        s1=rand(1:L-1) # get a random adjacent pair of sites
        s2=s1+1
        
        S1,S2=S[k,s1],S[k,s2] # get their states
    
        # see if the particle hops left or right
        if (S1==0)&(S2==1)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        elseif (S1==1)&(S2==0)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        end
             
    end
    S[k+1,:]=S[k,:]
end

# %%
# plot out a time-space map of the diffusion
heatmap(S,xlabel="position",ylabel="time steps")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1900)" points="
# 57.8546,360.065 520.315,360.065 520.315,11.811 57.8546,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1902">
#     <rect x="57" y="11" width="463" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   172.314,360.065 172.314,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   287.929,360.065 287.929,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.544,360.065 403.544,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   519.159,360.065 519.159,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,290.449 520.315,290.449
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,220.798 520.315,220.798
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,151.148 520.315,151.148
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,81.4967 520.315,81.4967
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,11.8458 520.315,11.8458
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 57.8546,11.811
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   172.314,360.065 172.314,354.842
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   287.929,360.065 287.929,354.842
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.544,360.065 403.544,354.842
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   519.159,360.065 519.159,354.842
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,290.449 64.7915,290.449
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,220.798 64.7915,220.798
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,151.148 64.7915,151.148
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,81.4967 64.7915,81.4967
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,11.8458 64.7915,11.8458
#   "/>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 172.314, 373.865)" x="172.314" y="373.865">50</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 287.929, 373.865)" x="287.929" y="373.865">100</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.544, 373.865)" x="403.544" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 519.159, 373.865)" x="519.159" y="373.865">200</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 294.949)" x="51.8546" y="294.949">1000</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 225.298)" x="51.8546" y="225.298">2000</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 155.648)" x="51.8546" y="155.648">3000</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 85.9967)" x="51.8546" y="85.9967">4000</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 16.3458)" x="51.8546" y="16.3458">5000</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 289.085, 397.6)" x="289.085" y="397.6">position</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">time steps</text>
# </g>
# <g clip-path="url(#clip1902)">
# <image width="462" height="348" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAc4AAAFcCAYAAABBSF74AAAIiElEQVR4nO3dXa6zRhAEUN/oLjRL
# y0IjfXkhErJsoGD4melzVuC3UnX34J/X6/fPC4j8++ef1+v1ev3+/H3r7wCu99fdPwAAeiI4ASAg
# OAEgIDgBICA4ASAgOAEg8OM5CrTlqQqMTXDCBYQpjOP37h8Ao/o/LF8vgQkj0TjhQpon9E/jhAsI
# TBiHq1oACAhOAAgITgAICE4ACDgOgpN4jgJj8hwFLuCqFsZhVAsAAY0TLqR5Qv8EJ9zA/hP6ZVQL
# AAFXtXAho1ron8YJAAHBCQABx0FwM+Nb6IvghAsJSeifUS0ABDROOIm3mjAmjRMAAoITAAKCEwAC
# vhwEjbmchbE5DoIDHABBPUa1ABAQnAAQEJwAEBCcABBwHASNuKaFGjROAAgITgAICE4ACAhOAAj4
# 5B4c4MtBUI+rWmjMdS2MzagWAAIaJ5zEGBfGZMcJjRnVwtg0TjiJxgljsuMEgIDGCY0Y0UINdpxw
# gHEs1KNxQkCrBAQn7CBAoS6jWggITEDjhAPsOKEewQkrhCMwZ1QLXxjLAp9onDARlMAWghPeCFBg
# iU/uAUBA44QvNE/gE40TAAIaJ6V5agKkPEehJGNYYC+jWgAICE4ACNhxUpodJ5Cy46QkO05gL42T
# 0jROIKVxUpLGCezlOAgAAka1MNFCgS2MainNjhNIGdUCQEBwAkBAcAJAwI6TkhwCAXtpnAAQ8ByF
# 0lzVAimNEwACdpyUZMcJ7KVxAkDAjpPS7DiBlOCEifEtsIXghC8EKfCJ4IQVxrnAnOCEHbRRqEtw
# wgHaKNTjOQoABHwAAXYwqoW6BCcEBCZgxwk7CFCoy44TAAJGtRDQNAGjWngjHIElRrUAENA44QvN
# E/jEjhPeCExgieCEicAEthCclOZbs0DKcRAABDROSjKWBfbSOAEg4DkKTLRQYAvBCSscEAFzRrUA
# EBCcABAwqoU3dp3AEsEJXwhQ4BOjWgAIaJwQ0EIBwQk7CFCoyyf3ICAwAcEJK3wAAZgzqoWAxgkI
# TthBgEJdghMOMMaFeuw4YQeNE+ryAQQACBjVwgFGtVCP4IRGjG+hBsEJjQlQGJvghJMY48KYHAcB
# QEBwAkDAqBYuYO8J4/ABBDiJHSeMyagWAAKCEwACRrXQmH0mjM1xEJzEjhPGZFQLAAHBCQABo1q4
# gL0njMNxEJzEjhPGJDihMe0SxmZUCxcQpjAOjRNOYlQLY9I44QIaJ4xDcMJDCFfog+CEGxjjQr8E
# JzyExgl98OUgAAi4qoWbaZrQF40TAAIaJ9zAcRD0y3EQ3MyoFvo

# %% [markdown]
# ---

# %% [markdown]
# ## 2.5 Summary points
#
# Diffusion can be modelled as the summation of many random hops.
#
#
# Simulations are made of many time steps of size $dt$. These can be any value as long as they are small enough.
# Careful scaling of the hop statistics is required if the particle statistics are to be independent of $dt$.
#
#
# Simulations can be performed by keeping an account of the particle positions.
#
#
# Alternatively, a simulation can be performed by keeping an account of the landscape instead.

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # ** Section 3. ** Interacting particles
# * **3.1** Diffusion-death process in 1D
# * **3.2** Simple reaction-diffusion process in 1D
# * **3.3** Simple reaction-diffusion process in 2D
# * **3.4** Two-species reaction-diffusion process in 1D
# * **3.5** Summary points

# %% [markdown]
# ---

# %% [markdown]
# ## 3.1 Diffusion-death process in 1D
#
# Landscape oriented simulations are useful for interacting systems.
# Consider a model of diffusion and spontaneous decay. The rules are
#
# 01 -> 10 with probability p
# 10 -> 01 with probability p
# 1 -> 0 with probability q
#
# per time step where $p=Ddt$ and $q=Qdt$.
# $D$ is the diffusion constant and $Q$ is a decay rate
#
# This is like the well-known radioactive decay model, but with diffusion.
# The two processes don't interfere so the particle number as function of time should obey
#
# $$ \frac{dN}{dt}=-QN ~~\mbox{ with solution}~~ N=N_0e^{-tQ}$$
#
#
# Let's check this with a full lattice $N_0=L$ as initial conditions

# %%
# parameters

D=5.0 # diffusion constant
Q=0.5 # decay constant

dt,T=0.01,10.0 # various time quantities
nt=Int(T/dt)
t=dt*collect(1:nt)

p=D*dt # hop probability 
q=Q*dt # decay probability 

L=200 # lattice size
S=ones(nt,L)   # this is the lattice space in time: column=time, row=lattice entry

for k=1:nt-1
    for j=1:L-1
        
        s1=rand(1:L-1) # get a random adjacent pair of sites
        s2=s1+1
        
        S1,S2=S[k,s1],S[k,s2] # get their states
    
        # see if the particle hops left or right
        if (S1==0)&(S2==1)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        elseif (S1==1)&(S2==0)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        end
        
        # death step. NB this is called L-1 times as I put it in the diffusion lopp 
        # It should really be L times, but if L is large, it won't matter too much
        s3=rand(1:L)
        S3=S[k,s3]
        if (S3==1)&(rand()<q)
            S[k,s3]=0
        end
        
    end
    S[k+1,:]=S[k,:]
end

# %%
p1=heatmap(S,xlabel="lattice site",ylabel="time step")
p2=plot(t,sum(S,2),ylabel="number of particles",label="simulation")
p2=plot!(t,L*exp.(-t*Q),color=[:black],xlabel="time",label="theory")
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2100)" points="
# 57.8546,360.065 223.61,360.065 223.61,11.811 57.8546,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2102">
#     <rect x="57" y="11" width="167" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   98.879,360.065 98.879,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   140.318,360.065 140.318,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   181.757,360.065 181.757,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   223.195,360.065 223.195,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,290.589 223.61,290.589
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,220.938 223.61,220.938
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,151.287 223.61,151.287
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,81.636 223.61,81.636
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,11.9852 223.61,11.9852
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 223.61,360.065
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 57.8546,11.811
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   98.879,360.065 98.879,354.842
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   140.318,360.065 140.318,354.842
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   181.757,360.065 181.757,354.842
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   223.195,360.065 223.195,354.842
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,290.589 60.3409,290.589
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,220.938 60.3409,220.938
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,151.287 60.3409,151.287
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,81.636 60.3409,81.636
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,11.9852 60.3409,11.9852
#   "/>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 98.879, 373.865)" x="98.879" y="373.865">50</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 140.318, 373.865)" x="140.318" y="373.865">100</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 181.757, 373.865)" x="181.757" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 223.195, 373.865)" x="223.195" y="373.865">200</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 295.089)" x="51.8546" y="295.089">200</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 225.438)" x="51.8546" y="225.438">400</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 155.787)" x="51.8546" y="155.787">600</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 86.136)" x="51.8546" y="86.136">800</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 16.4852)" x="51.8546" y="16.4852">1000</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 140.732, 397.6)" x="140.732" y="397.6">lattice site</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">time step</text>
# </g>
# <g clip-path="url(#clip2102)">
# <image width="166" height="348" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAKYAAAFcCAYAAABC9sW8AAATFUlEQVR4nO2d3ZLkqA6EPRX9oPNo
# +6AnYs/FrmdpNwYhJJGC/G52o7rK5ieRhIQ9v67r6+/LiP/9/df19eu31eXg2L1/SHxWN4CQGhQm
# geQoYf7v77+mfv/16/f0NYiMo4RJYeXhKGGSPFCYBBIKk0BCYRJIKMwBmGCPg8IkkFCYQmgtYzET
# JieOWEKLSSChMIXQG8RylDBnwg2WMmMxEybr0MSSoywmyQOFKYQxZiwUJoGEwhTA2Dmeo4TJDVoe
# WPkRsGu/kDERZhZRZmknOcyVkzxMC5NWiHhAi0kgOUqYrJPn4ShhkjxQmB0YQ6+BwiSQmOUxd4TW
# ch20mASSo4Q5YtlpLdcyJcxsk5epraczJUxONPFCLcxdNzwEg6NiTJKHX1b/akW2eLPFTn3JCi0m
# gYTCJJBQmAQSCpNAwnQRgUQtTO5aiSd05QSSox7fJXmgxSSQHPX4LjdseaDFJJBQmAQS5jErZAlN
# dmZYmLcgM06epM07L7hMDAsz6zsmM7b5ZFQWM6O1JLng5ucBFx0GFCaBhMIkkByz+SG5oMV8wEWH
# AXflBJLPddFKEDzoygvoDXAYEiYnjkRBi0kgmRbmTumjnfqSHVpMAgmFSSD5XNcZLkx6FpObOwzE
# FjP7pEkW3gkLNAtiYWYW5XXlb/9piIS5ixXZpR8ncNRz5SQPImFSeCQaposIJBQmgYTCfMCwBQMK
# k0ByVLpIwkl9RYaniwgkR+Uxs7STFM/8tCYto1XM1l7ynU8mizcLxZoHkxjzuvAmXbvYTlmk6Jil
# izK6e4IL85gEko/U0p1mEU/qKyLHPFpxXef0cweGXDknlkRhGmNyR0usMN/8IFhUhDaQOcyFSXdP
# LDjupVpcODqix2y7POYOi4c4xZgUBpnljzAtXBxFSaw45hUxI5zUV1S2izEt4AZpPX+EuYuVoKj2
# YEuLabHAKPC1mG5+CLFi21o5Mwy5+SZMq5QRIbMMv7i1JzyUkAD1WaSsRM/rD2HSfZEa0aHN9v8s
# dLb2kn/YMl00Czc+6zlCmE+rSSuKzw9hcsIIAkdYzOv6uamj1cTmGGGSXBwlTFrIPBwlTL51JA8q
# YXLizmJF+szFYlK4e7Eip6sSpmQFUZx7ET2XX6F3A6BcMKzu4OK2+UEt66G2i3znqF35CAxF/mOb
# zQ+t0plYLmRaTNJlhfc4Vpi06NgcK0wyRvSjKkdVfkZj36z93IFvwpROXNbNDYU2R+Q/7ThsMbOK
# 8g0KFRPGmA12W4SZ2O6lWmQPeLqIQEJXTiChMAkkxwuzFXYwJFnHccIcFRvFuQY3Ye4yocxW

# %% [markdown]
# ---

# %% [markdown]
# ## 3.2 Simple reaction-diffusion process in 1D
#
# In the last case the particles weren't really interacting (apart from bumping into each other).
# Now consider a model with real interactions.
#
# We consider the reaction A+A->0 with diffusion.
#
# This is a more interesting problem as their are interactions
#
# 01 -> 10 with probability p
# 10 -> 01 with probability p
# 11 -> 00 with probability q
#
# per time step. We have $p=Ddt/2$ and $q=Qdt$ with $D$ and $Q$ constants.
#
# The differential equation typically used to describe this problem is
#
# $$ \frac{dA}{dt}=-\kappa A^2 ~~\mbox{ with solution}~~ A=\frac{1}{\kappa t}$$
#
# So that the prediction is the particle number goes down at a rate $1/t$.
#
# We start with a full lattice and see what happens

# %%
# parameters

D=5.0 # diffusion rate
Q=1.0 # reaction rate

dt,T=0.05,200.0 # time-related quantities
nt=Int(T/dt)
t=dt*collect(1:nt)

p=D*dt # hop probability 
q=Q*dt   # reaction probability

L=1000 # lattice size
S=ones(nt,L) # lattice space

for k=1:nt-1
    for j=1:L-1
        
        s1=rand(1:L-1) # get a random adjacent pair of sites
        s2=s1+1
        
        S1,S2=S[k,s1],S[k,s2] # get their states
    
        # see if the particle hops left or right
        if (S1==0)&(S2==1)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        elseif (S1==1)&(S2==0)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        elseif (S1==1)&(S2==1)&(rand()<q)
            S[k,s1],S[k,s2]=0,0
        end
        
    end
    S[k+1,:]=S[k,:]
end

# %%
heatmap(S,xlabel="lattice site",ylabel="time step")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2300)" points="
# 57.8546,360.065 520.315,360.065 520.315,11.811 57.8546,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2302">
#     <rect x="57" y="11" width="463" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   150.115,360.065 150.115,11.811
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   242.608,360.065 242.608,11.811
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   335.1,360.065 335.1,11.811
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   427.592,360.065 427.592,11.811
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.084,360.065 520.084,11.811
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,273.045 520.315,273.045
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,185.982 520.315,185.982
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,98.9182 520.315,98.9182
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,11.8546 520.315,11.8546
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 57.8546,11.811
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   150.115,360.065 150.115,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   242.608,360.065 242.608,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   335.1,360.065 335.1,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   427.592,360.065 427.592,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.084,360.065 520.084,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,273.045 64.7915,273.045
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,185.982 64.7915,185.982
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,98.9182 64.7915,98.9182
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,11.8546 64.7915,11.8546
#   "/>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 150.115, 373.865)" x="150.115" y="373.865">200</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 242.608, 373.865)" x="242.608" y="373.865">400</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 335.1, 373.865)" x="335.1" y="373.865">600</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 427.592, 373.865)" x="427.592" y="373.865">800</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.084, 373.865)" x="520.084" y="373.865">1000</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 277.545)" x="51.8546" y="277.545">1000</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 190.482)" x="51.8546" y="190.482">2000</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 103.418)" x="51.8546" y="103.418">3000</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 16.3546)" x="51.8546" y="16.3546">4000</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 289.085, 397.6)" x="289.085" y="397.6">lattice site</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">time step</text>
# </g>
# <g clip-path="url(#clip2302)">
# <image width="462" height="348" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAc4AAAFcCAYAAABBSF74AAAgAElEQVR4nO2d2xLcNq5Flal8aD4t
# D/OZqfJ58PRxW9GFF5DYANaqSs3Y7pZI3EFS6j+O488fB7jyz4+/jz//+Mt7GAAA5WmJx//ZMxQt
# /vnxt/cQ/h+VpKkkEwCA3XxiYEs8Lpk4lRKVwlgAAKrTE4tLJk4FlBKmStcLsWHVAjLQYsd/VNvj
# VEoSSmMBAIA2ynScikujKmOhUwALsCOoQonEqdrZKQQaVdlAPP784y8JmwbopdduSy3VkiQAAOCK
# nvxQouP8QNIEAG/oyvXobapKdZxwDZ04AEA7pTpOuIakCTPQQfWBvOJD4nQGJ4KoKJ5UjwDyig+J
# EwCGIAGMQbGsR69OSiZOFcNlbxGio+JLkcDn9ejVCYeDAAAAOijZccIv6BgA1oKP5aNc4sSIf4e3
# vcAM2M47LM1qM2LDLNUCwDDs00NFynWcaihU7ApjgJiwYtEGMsoFHWdx6BgAAPqg4ywOSRNgPXSc
# uSBxFgeHBlgPBWouSJwAAAAdkDgd8e722N8EK7xtGWAGXrkXCO8Tid73B6gCfqbLSANB4gSAaVi5
# uIeVHW1GGohyiVOt8sOhAHKDj+vDS94BAESh+8xBuY7zG5XuU2UcADNgx8+QNPNAx1kYHBkA4Cc9
# 8bBkx0ll/BOSJliDb92DbLTpiYclE6caOBRE52PDFGPXsLqTC5ZqnfF2KO/7Q3ywIagGHScADEPS
# 7IPVpRzQcQIAbIAiQ4dZXdBxOkL1CRnAjtsgaeowqws6TgAAKIFV11+646RSBpgDH2oDOWlg1fWX
# TpwAMAe/sNMGy7S5KJU4zw6uasy7AhEBD2bhwAtEwirmscdZHAIfAEAfpTpO+DckTYC1sLLjxyrZ
# l0uckYw40lihHthnGxSnfnxkb22r5RInRvwTgh4AVME67pdLnJESxqokz74mzIINPRMpzkA/HA4S
# hcAEimCX7SCrvNBxirKy2wQYhUQAULTjpBIE6Ae/AfhJycQJAAAwCku1AACQEp7jNKL6UhOFA8yC
# DYE6HxtdFe9Zqg0Ee0wAAM/siJPlOs7IzBgDXQKAL/hgHkicRVj16ikAeGb1siH8YteqHIkzELNJ
# j6VesIICrA18bi+7fh+WxFkIfnQYAGAeEmcgSHygAl0UqMJS7QKqJx72OsES7OgZCoy97LJHHkcB
# ADCEfU0/OBwEABAMkqYPu08ukzgLwvIaAGTBo1hhqTYQFgZCRQwAMAcdZyAsEh4nc2E1le2r8tw9
# 8JI3ibMgJE9YCSsasAsvWyubOKsnDpIngD0UDTVgjxMAzGEvHTJTtuOMD

# %%
# check the theoretical prediction of a decay of particles that is 1/t with time

npt=sum(S,2) # number of particles with time

p1=plot(t,npt,xlabel="time",ylabel="number of particles",label="simulation")
p1=plot!(t,L./t,ylim=[0,L],label="theory (1/t)",color=[:black])

p2=plot(t,npt,xscale = :log10,yscale = :log10,xlabel="time",ylabel="number of particles")
p2=plot!(t,L./t,xscale = :log10,yscale = :log10,ylim=[1,L],label="theory (1/t)",color=[:black])
p2=plot!(t,L./sqrt.(t),xscale = :log10,yscale = :log10,ylim=[1,L],color=[:green],label="1/t^(1/2)",legend = :bottomleft)

plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2500)" points="
# 57.8546,360.065 280.831,360.065 280.831,11.811 57.8546,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2502">
#     <rect x="57" y="11" width="224" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   113.557,360.065 113.557,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   169.315,360.065 169.315,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.073,360.065 225.073,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   280.831,360.065 280.831,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,360.065 280.831,360.065
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,290.415 280.831,290.415
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,220.764 280.831,220.764
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,151.113 280.831,151.113
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,81.4619 280.831,81.4619
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,11.811 280.831,11.811
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 280.831,360.065
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 57.8546,11.811
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   113.557,360.065 113.557,354.842
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   169.315,360.065 169.315,354.842
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.073,360.065 225.073,354.842
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   280.831,360.065 280.831,354.842
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 61.1992,360.065
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,290.415 61.1992,290.415
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,220.764 61.1992,220.764
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,151.113 61.1992,151.113
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,81.4619 61.1992,81.4619
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,11.811 61.1992,11.811
#   "/>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 113.557, 373.865)" x="113.557" y="373.865">50</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 169.315, 373.865)" x="169.315" y="373.865">100</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.073, 373.865)" x="225.073" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 280.831, 373.865)" x="280.831" y="373.865">200</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 364.565)" x="51.8546" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 294.915)" x="51.8546" y="294.915">200</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 225.264)" x="51.8546" y="225.264">400</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 155.613)" x="51.8546" y="155.613">600</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 85.9619)" x="51.8546" y="85.9619">800</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 16.311)" x="51.8546" y="16.311">1000</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 169.343, 397.6)" x="169.343" y="397.6">time</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">number of particles</text>
# </g>
# <polyline clip-path="url(#clip2502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,48.0295 57.9103,74.4968 57.9661,100.964 58.0219,121.163 58.0776,134.397 58.1334,149.023 58.1891,162.257 58.2449,170.615 58.3006,184.545 58.3564,193.6
#   58.4122,199.172 58.4679,204.047 58.5237,211.709 58.5794,220.764 58.6352,227.032 58.691,230.515 58.7467,235.39 58.8025,240.266 58.8582,243.052 58.914,244.445
#   58.9697,247.928 59.0255,250.714 59.0813,252.107 59.137,256.286 59.1928,259.768 59.2485,263.251 59.3043,266.733 59.36,269.519 59.4158,272.305 59.4716,275.091
#   59.5273,276.484 59.5831,278.574 59.6388,280.663 59.6946,281.36 59.7504,283.449 59.8061,284.146 59.8619,285.539 59.9176,286.932 59.9734,289.022 60.0291,289.718
#   60.0849,291.111 60.1407,292.504 60.1964,292.504 60.2522,293.201 60.3079,294.594 60.3637,295.987 60.4194,296.683 60.4752,297.38 60.531,298.076

# %% [markdown]
# ---

# %% [markdown]
# ## 3.3 Two-species reaction-diffusion process in 1D
#
# We now consider a more general reaction process with two species: A+B->0
#
# The rules are
#
# 0X -> X0 with probability p
# X0 -> 0X with probability p
#
# where X can be an A or B particle, and the reaction is
#
# AB -> 00 with probability q
# BA -> 00 with probability q
#
#
# The differential equations typically used to describe this problem are
#
# $$ \frac{dA}{dt}=-\kappa AB ~~\mbox{and}~~ \frac{dA}{dt}=-\kappa AB ~~\mbox{ with solution}~~ A\propto\frac{1}{t}~~\mbox{and}~~B\propto\frac{1}{t}$$
#
#
# In this case we start with a random distribution of particles
#
# We will use $1$ for an A particles and $-1$ for a B particles

# %%
# parameters

D=5.0 # diffusion rate
Q=1.0 # reaction rate

dt,T=0.05,200.0 # time-related quantities
nt=Int(T/dt)
t=dt*collect(1:nt)

p=D*dt # hop probability 
q=Q*dt   # reaction probability

L=1000 # lattice size
S=rand([-1,0,1],nt,L) # lattice space

for k=1:nt-1
    for j=1:L-1
        
        s1=rand(1:L-1) # get a random adjacent pair of sites
        s2=s1+1
        
        S1,S2=S[k,s1],S[k,s2] # get their states
    
        # diffuses any particle left or right
        if (S1==0)&(S2!=0)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        elseif (S1!=0)&(S2==0)&(rand()<p)
            S[k,s1],S[k,s2]=S2,S1
        elseif (S1!=S2)&(S1!=0)&(S2!=0)&(rand()<q)
            S[k,s1],S[k,s2]=0,0
        end
        
    end
    S[k+1,:]=S[k,:]
end

# %%
heatmap(S,xlabel="lattice site",ylabel="time step")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2700)" points="
# 57.8546,360.065 520.315,360.065 520.315,11.811 57.8546,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2702">
#     <rect x="57" y="11" width="463" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   150.115,360.065 150.115,11.811
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   242.608,360.065 242.608,11.811
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   335.1,360.065 335.1,11.811
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   427.592,360.065 427.592,11.811
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.084,360.065 520.084,11.811
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,273.045 520.315,273.045
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,185.982 520.315,185.982
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,98.9182 520.315,98.9182
#   "/>
# <polyline clip-path="url(#clip2702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,11.8546 520.315,11.8546
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 57.8546,11.811
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   150.115,360.065 150.115,354.842
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   242.608,360.065 242.608,354.842
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   335.1,360.065 335.1,354.842
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   427.592,360.065 427.592,354.842
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.084,360.065 520.084,354.842
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,273.045 64.7915,273.045
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,185.982 64.7915,185.982
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,98.9182 64.7915,98.9182
#   "/>
# <polyline clip-path="url(#clip2700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,11.8546 64.7915,11.8546
#   "/>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 150.115, 373.865)" x="150.115" y="373.865">200</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 242.608, 373.865)" x="242.608" y="373.865">400</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 335.1, 373.865)" x="335.1" y="373.865">600</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 427.592, 373.865)" x="427.592" y="373.865">800</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.084, 373.865)" x="520.084" y="373.865">1000</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 277.545)" x="51.8546" y="277.545">1000</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 190.482)" x="51.8546" y="190.482">2000</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 103.418)" x="51.8546" y="103.418">3000</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 16.3546)" x="51.8546" y="16.3546">4000</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 289.085, 397.6)" x="289.085" y="397.6">lattice site</text>
# </g>
# <g clip-path="url(#clip2700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">time step</text>
# </g>
# <g clip-path="url(#clip2702)">
# <image width="462" height="348" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAc4AAAFcCAYAAABBSF74AAAgAElEQVR4nO19u5IlNw5ldoX+qceV
# IVsxhnx92hjrK8ZuY1zpnyai19ilBo3C4+DFZN6qE9HRVfcmSSSTCRDAAevLt6+/fb/+P37+89fr
# P//495VFpX2l7S9//XF9+/rPsTbotfy6jFwRGTr7vxvevWTvlbbTfvbaZp6/1kZaI9d1/TAO70f6
# fn0m9ZNFRx8c1ntd1TfR8Tv1m9fXXbrwE/8PmTmMtHmjv9z5sP7zj39fP//5a6otVSYW6DWaUtP6
# R66dMpoaEMWPfHYCvGeYuVfaL38enRsabVxLHvo7N5bcONLPIzLQ79Dnzg32JFB9Y+kFT2dQQ9cJ
# SV/R37178+Sx+v6Ej4wti7R58y+ZGXghstg0oEaqohRoG2Q81JijqHrUnjdxgkGd2Gho88B/tuSx
# nqVmjJFNADegiAFc10rjSvMneaqIXFUDut7rjs241ceUYVyQ9JN2b5GNAHJPmb4/sQcthrOyaDsW
# fpfCtYxKZgzq7VRR9ag9RXh6yBdV+trnknHpvueoIUSMmWToo14klQkZKxLO1tDhTVax+l6GKuuF
# cBk9b1P6nX6GyOGFgXfjqR5vRm6kTavHmcXOmL6msDQlFMlvSeDeQRYZD1a6x0iIeje6nwH6jBFI
# +WXvGrQ/NJTMPWDUK0TlkvKqWaAKq+u9j3pwKFDdhHiflXSU1/cnZEyFbFsMZ8eC6FhQiGLUyB6a
# YbLCX0j7qHwWkPAwHUe7R0n2Dvkq0MhP1xVX/Pz3jCHoyA+j6QOa50TkskhCnpynbJJQdHk60X48
# 75B/Tr1bC11G76ke4F3onq8fDGdHyHV3W4qsgkXaI4YSNWxVWJ6ZNc5SuJn7n4blYWUheXJReTKh
# bb458QxZxLBzr9TaCEnjRz3nrKGtvtOdOdId467ru+7bu+bT64yhe76OYNVO7Z6myTl3GJqsIXia
# p5FFdDPj9ZPJiUrkHc8AS2FlyeBpqQapH+kerPm5e4106IGf//z1B+OXMYRZ77SzTwt36OmuMPPd
# 6LqHtMd54kLoUppo/9pnkfZVWN4EBzofdyvQDDrychRVg8t/tq63xtLC7dFcdSasS69H1wQ1XFF0
# MXB3R78QgiPar2eg7jRer+DlaiH2KI7wOCfGrir/SL4T7auLJBQd/wnoyv9azNaoUcvIhTJSrTWB
# htQlglDUQ0bljayzTOF5BbS9xIDdhU6i0yt4d09A9pm9IwftZsOtMasLBWElRtAVwqpQ+iNjdGK3
# Me6cI2oILBKNlQeW+pO+08DH1cho2vVdZJ9IbvPODVgn65UbnahuWf2hb

# %%
# Let's examine the decay with time

Anum=sum(S.==1,2) # extract the numbers of A particles left at each time step
Bnum=sum(S.==-1,2) # same for B particles

p1=plot(t,Anum,xlabel="time",ylabel="number of particles",label="A species")
p1=plot!(t,Bnum,label="B species")

p2=plot(t,Anum,xscale = :log10,yscale = :log10,label="A species",xlabel="time",ylabel="number of particles")
p2=plot!(t,Bnum,xscale = :log10,yscale = :log10,label="B species")
p2=plot!(t,L./t,xscale = :log10,yscale = :log10,ylim=[1,L^2],color=[:black],label="theory (1/t)")
p2=plot!(t,L./t.^0.5,xscale = :log10,yscale = :log10,label="1/t^(1/4)",color=[:green])
p2=plot!(t,L./t.^0.25,xscale = :log10,yscale = :log10,label="1/t^(1/4)",legend = :topright)
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2900)" points="
# 51.265,360.065 277.536,360.065 277.536,11.811 51.265,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2902">
#     <rect x="51" y="11" width="227" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   107.79,360.065 107.79,11.811
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   164.372,360.065 164.372,11.811
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   220.954,360.065 220.954,11.811
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   277.536,360.065 277.536,11.811
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.265,332.84 277.536,332.84
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.265,276.121 277.536,276.121
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.265,219.402 277.536,219.402
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.265,162.683 277.536,162.683
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.265,105.964 277.536,105.964
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.265,49.2455 277.536,49.2455
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,360.065 277.536,360.065
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,360.065 51.265,11.811
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   107.79,360.065 107.79,354.842
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   164.372,360.065 164.372,354.842
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.954,360.065 220.954,354.842
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   277.536,360.065 277.536,354.842
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,332.84 54.659,332.84
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,276.121 54.659,276.121
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,219.402 54.659,219.402
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,162.683 54.659,162.683
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,105.964 54.659,105.964
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,49.2455 54.659,49.2455
#   "/>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 107.79, 373.865)" x="107.79" y="373.865">50</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 164.372, 373.865)" x="164.372" y="373.865">100</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 220.954, 373.865)" x="220.954" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 277.536, 373.865)" x="277.536" y="373.865">200</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 337.34)" x="45.265" y="337.34">50</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 280.621)" x="45.265" y="280.621">100</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 223.902)" x="45.265" y="223.902">150</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 167.183)" x="45.265" y="167.183">200</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 110.464)" x="45.265" y="110.464">250</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 53.7455)" x="45.265" y="53.7455">300</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 164.4, 397.6)" x="164.4" y="397.6">time</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">number of particles</text>
# </g>
# <polyline clip-path="url(#clip2902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,41.3049 51.3215,52.6487 51.3781,60.5893 51.4347,68.53 51.4913,76.4706 51.5479,84.4113 51.6044,91.2176 51.661,96.8895 51.7176,103.696 51.7742,111.636
#   51.8308,119.577 51.8874,122.98 51.9439,124.115 52.0005,127.518 52.0571,132.055 52.1137,135.458 52.1703,141.13 52.2268,144.533 52.2834,151.34 52.34,154.743
#   52.3966,158.146 52.4532,164.952 52.5098,167.221 52.5663,169.49 52.6229,172.893 52.6795,175.162 52.7361,178.565 52.7927,181.968 52.8492,183.102 52.9058,183.102
#   52.9624,185.371 53.019,186.505 53.0756,189.909 53.1322,193.312 53.1887,197.849 53.2453,200.118 53.3019,203.521 53.3585,203.521 53.4151,203.521 53.4716,204.655
#   53.5282,205.79 53.5848,208.059 53.6414,208.059 53.698,210.327 53.7546,211.462 53.8111,211.462 53.8677,212.596 53.9243,213.731 53.9809,214.865 54.0375,215.999
#   54.094,217.134 54.1506,218.2

# %% [markdown]
# ---

# %% [markdown]
# ## 3.4 Simple reaction-diffusion process in 2D
#
# And finally, we generalise the A+A->0 reaction to 2D.
#
# For an $L\times L$ 2D lattice there are $L(L-1)$ horizontal bonds and the same for vertical ones.
# (a bond is a pair of adjacent sites).
#
# Apart from taking into account these extra sites, it is straightforward to adapt the 1D  code.

# %%
# parameters

D=5.0 # diffusion rate
Q=1.0 # reaction rate

dt,T=0.05,50.0 # time-related quantities
nt=Int(T/dt)
t=dt*collect(1:nt)

p=D*dt   # hop probability 
q=Q*dt   # reaction probability

L=100          # lattice size
S=ones(nt,L,L) # lattice space

for k=1:nt-1
    for j=1:L*(L-1)
        
        # row diffusion or reaction step
        sr1,sc1=rand(1:L-1),rand(1:L)
        sr2=sr1+1
        
        S1=S[k,sr1,sc1]
        S2=S[k,sr2,sc1]
        
        if (S1==0)&(S2==1)&(rand()<p)
            S[k,sr1,sc1],S[k,sr2,sc1]=S2,S1
            elseif (S1==1)&(S2==0)&(rand()<p)
            S[k,sr1,sc1],S[k,sr2,sc1]=S2,S1
            elseif (S1==1)&(S2==1)&(rand()<q)
            S[k,sr1,sc1],S[k,sr2,sc1]=0,0
        end
    
        # column diffusion or reaction step
        sr1,sc1=rand(1:L),rand(1:L-1)
        sc2=sc1+1
        
        S1=S[k,sr1,sc1]
        S2=S[k,sr1,sc2]
        
        if (S1==0)&(S2==1)&(rand()<p)
            S[k,sr1,sc1],S[k,sr1,sc2]=S2,S1
            elseif (S1==1)&(S2==0)&(rand()<p)
            S[k,sr1,sc1],S[k,sr1,sc2]=S2,S1
            elseif (S1==1)&(S2==1)&(rand()<q)
            S[k,sr1,sc1],S[k,sr1,sc2]=0,0
        end
        
    end
    S[k+1,:,:]=S[k,:,:]
end

# %%
# short script for plotting out a movie of the particles

for k=10:10:500
    s=find(S[k,:,:].==1)
    x,y=ind2sub((L,L),s);
    p1 = scatter(x,y,xlim=[1,L],ylim=[1,L],title=("step $k"),legend=false)
    IJulia.clear_output(true)
    display(p1)
    sleep(0.3)
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2900)" points="
# 35.5169,375.813 580.315,375.813 580.315,31.4961 35.5169,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2902">
#     <rect x="35" y="31" width="546" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7442,375.813 45.7442,31.4961
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   175.532,375.813 175.532,31.4961
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   305.32,375.813 305.32,31.4961
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   435.108,375.813 435.108,31.4961
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.896,375.813 564.896,31.4961
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,369.35 580.315,369.35
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,287.323 580.315,287.323
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,205.295 580.315,205.295
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,123.268 580.315,123.268
#   "/>
# <polyline clip-path="url(#clip2902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,41.2409 580.315,41.2409
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 35.5169,31.4961
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7442,375.813 45.7442,370.649
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   175.532,375.813 175.532,370.649
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   305.32,375.813 305.32,370.649
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   435.108,375.813 435.108,370.649
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.896,375.813 564.896,370.649
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,369.35 43.6889,369.35
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,287.323 43.6889,287.323
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,205.295 43.6889,205.295
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,123.268 43.6889,123.268
#   "/>
# <polyline clip-path="url(#clip2900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,41.2409 43.6889,41.2409
#   "/>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.7442, 389.613)" x="45.7442" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 175.532, 389.613)" x="175.532" y="389.613">25</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 305.32, 389.613)" x="305.32" y="389.613">50</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 435.108, 389.613)" x="435.108" y="389.613">75</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.896, 389.613)" x="564.896" y="389.613">100</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 373.85)" x="29.5169" y="373.85">0</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 291.823)" x="29.5169" y="291.823">25</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 209.795)" x="29.5169" y="209.795">50</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 127.768)" x="29.5169" y="127.768">75</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 45.7409)" x="29.5169" y="45.7409">100</text>
# </g>
# <g clip-path="url(#clip2900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 307.916, 18)" x="307.916" y="18">step 500</text>
# </g>
# <circle clip-path="url(#clip2902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="227.447" cy="366.069" r="4"/>
# <circle clip-path="url(#clip2902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="227.447" cy="366.069" r="3"/>
# <circle clip-path="url(#clip2902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="258.597" cy="366.069" r="4"/>
# <circle clip-path="url(#clip2902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="258.597" cy="366.069" r="3"/>
# <circle clip-path="url(#clip2902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="346.852" cy="359.506" r="4"/>
# <circle clip-path="url(#clip2902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="346.852" cy="359.506" r="3"/>
# <circle clip-path="url(#clip2902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="455.874" cy="349.663" r="4"/>
# <circle clip-path="url(#clip2902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="455.874" cy="349.663" r="3"/>
# <circle clip-path="url(#clip2902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="82.0848" cy="346.382" r="4"/>
# <circle clip-path="url(#clip2902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="82.

# %% [markdown]
# ---

# %% [markdown]
# ## 3.5 Summary points
#
# Lanscape-based simulations are efficient when there are many interacting particles.
#
#
# When the particle interact, and there is diffusion correlations build up.
# This can make the behaviour significantly different from the prediction of naive theory.
#
#
# Stochastic simulations are a powerful tool form modelling interactions in the real world.
