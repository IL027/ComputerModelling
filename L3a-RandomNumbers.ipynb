# %%
using Plots, LaTeXStrings

# %% [markdown]
# # IL027 Core Lecture 3 part a - Random Numbers
#
# ### Christoph Ortner
#
# ### Mathematics Institute
#
# ## Overview
#
# - Review of conditional `if`
# - generating random numbers: `rand, randn, randexp`
# - applications: Monte Carlo simulation of $\pi$, Brownian motion
# - `Distributions.jl` package
# - fitting of distribution parameters

# %% [markdown]
# ## Review: Conditionals
#
# Before we get into the main topic of the lecture we briefly review a control flow statement that we introduced in L1-Assignment, but did not cover properly in L1 and L2. For example, consider implementing the Heaviside function
# $$
#     H(x) = \begin{cases}
#         1, & x < 0  \\
#         0, & x \geq 0
#     \end{cases}
# $$
# This can be achieved with an `if` statement.

# %%
function H(x)
    if x < 0 
        return 1.0 
    else 
        return 0.0 
    end
end
# Out:
# H (generic function with 1 method)

# %%
x = linspace(-1, 1, 100)
plot(x, H.(x), lw = 3, xlims = (-1.1, 1.1), ylims = (-0.5, 1.5), label="H")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7900)" points="
# 39.1436,375.813 580.315,375.813 580.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7902">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   63.7423,375.813 63.7423,11.811
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   186.736,375.813 186.736,11.811
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.729,375.813 309.729,11.811
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   432.723,375.813 432.723,11.811
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   555.716,375.813 555.716,11.811
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,284.813 580.315,284.813
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,193.812 580.315,193.812
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,102.812 580.315,102.812
#   "/>
# <polyline clip-path="url(#clip7902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,11.811 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.7423,375.813 63.7423,370.353
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   186.736,375.813 186.736,370.353
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.729,375.813 309.729,370.353
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   432.723,375.813 432.723,370.353
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   555.716,375.813 555.716,370.353
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 47.2612,375.813
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,284.813 47.2612,284.813
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,193.812 47.2612,193.812
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,102.812 47.2612,102.812
#   "/>
# <polyline clip-path="url(#clip7900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,11.811 47.2612,11.811
#   "/>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 63.7423, 389.613)" x="63.7423" y="389.613">-1.0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 186.736, 389.613)" x="186.736" y="389.613">-0.5</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.729, 389.613)" x="309.729" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 432.723, 389.613)" x="432.723" y="389.613">0.5</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 555.716, 389.613)" x="555.716" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 380.313)" x="33.1436" y="380.313">-0.5</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 289.313)" x="33.1436" y="289.313">0.0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 198.312)" x="33.1436" y="198.312">0.5</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 107.312)" x="33.1436" y="107.312">1.0</text>
# </g>
# <g clip-path="url(#clip7900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 16.311)" x="33.1436" y="16.311">1.5</text>
# </g>
# <polyline clip-path="url(#clip7902)" style="stroke:#009af9; stroke-width:3; stroke-opacity:1; fill:none" points="
#   63.7423,102.812 68.7117,102.812 73.6812,102.812 78.6506,102.812 83.62,102.812 88.5895,102.812 93.5589,102.812 98.5283,102.812 103.498,102.812 108.467,102.812
#   113.437,102.812 118.406,102.812 123.375,102.812 128.345,102.812 133.314,102.812 138.284,102.812 143.253,102.812 148.223,102.812 153.192,102.812 158.162,102.812
#   163.131,102.812 168.1,102.812 173.07,102.812 178.039,102.812 183.009,102.812 187.978,102.812 192.948,102.812 197.917,102.812 202.886,102.812 207.856,102.812
#   212.825,102.812 217.795,102.812 222.764,102.812 227.734,102.812 232.703,102.812 237.672,102.812 242.642,102.812 247.611,102.812 252.581,102.812 257.55,102.812
#   262.52,102.812 267.489,102.812 272.459,102.812 277.428,102.812 282.397,102.812 287.367,102.812 292.336,102.812 297.306,102.812 302.275,102.812 307.245,102.812
#   312.214,284.813 317.183,284.813 322.153,284.813 327.122,284.813 332.092,284.813 337.061,284.813 342.031,284.813 347,284.813 351.969,284.813 356.939,284.813
#   361.908,284.813 366.878,284.813 371.847,284.813 376.817,284.813 381.786,284.813 386.756,284.813 391.725,284.813 396.694,284.813 401.664,284.813 406.633,284.813
#   411.603,284.813 416.572,284.813 421.542,284.813 426.511,284.813 431.48,284.813 436.45,284.813 441.419,284.813 446.389,284.813 451.358,284.813 456

# %% [markdown]
# The general form of writing `if` statements can be looked up in the help text:

# %%
?if
# Out:
# search: if ifft ifft! ifelse ifftshift gif diff @gif shift! UniformScaling
# `if`-`elseif`-`else` performs conditional evaluation, which allows portions of code to be evaluated or not evaluated depending on the value of a boolean expression. Here is the anatomy of the `if`-`elseif`-`else` conditional syntax:
#
# ```
# if x < y
#     println("x is less than y")
# elseif x > y
#     println("x is greater than y")
# else
#     println("x is equal to y")
# end
# ```
#
# If the condition expression `x < y` is true, then the corresponding block is evaluated; otherwise the condition expression `x > y` is evaluated, and if it is true, the corresponding block is evaluated; if neither expression is true, the `else` block is evaluated. The `elseif` and `else` blocks are optional, and as many `elseif` blocks as desired can be used.

# %% [markdown]
# As usual, there are many alternative ways to implement `H`, e.g., using the ternary operator,
# ```
# H1(x) = x < 0 ? 1.0 : 0.0
# ```
# or simply a logical mask,
# ```
# H2(x) = Float64(x < 0)
# ```

# %% [markdown]
# **Question:** write a function `incircle` that checks whether two coordinates `x`, `y` belong to the unit circle

# %% [markdown]
# ## Random Numbers

# %%
?random
# Out:
# search: RandomDevice
#
# Couldn't find random
# Perhaps you meant rand, rand!, randn, randn!, randexp, randjump or randperm
# No documentation found.
#
# Binding `random` does not exist.

# %%
?rand
# Out:
# search: rand randn rand! randn! randexp randperm randjump randexp! randcycle
# ```
# rand([rng=GLOBAL_RNG], [S], [dims...])
# ```
#
# Pick a random element or array of random elements from the set of values specified by `S`; `S` can be
#
#   * an indexable collection (for example `1:n` or `['x','y','z']`), or
#   * a type: the set of values to pick from is then equivalent to `typemin(S):typemax(S)` for integers (this is not applicable to [`BigInt`](@ref)), and to $[0, 1)$ for floating point numbers;
#
# `S` defaults to [`Float64`](@ref).

# %%
# compute a single random number in [0, 1]
rand()
# Out:
# 0.2740513181530355

# %%
# compute many random numbers 
for n = 1:5 
    println(rand())
end
# Out:
# 0.24287324155439594
# 0.1455946985980905
# 0.154593338751414
# 0.8086864973741168
# 0.16614381209951623

# %%
# or get a vector of random numbers 
x = rand(5)
# Out:
# 5-element Array{Float64,1}:
#  0.672149
#  0.585332
#  0.388073
#  0.835277
#  0.901907

# %%
println("random integer between 1 and 10:")
@show rand(1:10)
println()
println("random element from a collection:")
@show rand(["the", "quick", "brown", "fox"])
println()
println("A 2 x 2 matrix of random integers:")
@show rand(1:5, (2,2))
;
# Out:
# random integer between 1 and 10:
# rand(1:10) = 4
#
# random element from a collection:
# rand(["the", "quick", "brown", "fox"]) = "fox"
#
# A 2 x 2 matrix of random integers:
# rand(1:5, (2, 2)) = [2 4; 4 3]

# %% [markdown]
# Specifically, `rand()` draws a random number from the **Uniform Distribution** on $[0, 1]$. More precisely, this means that, if `x = rand()` and $[a, b] \subset [0, 1]$, then
# $$
#     \mathbb{P}\big( x \in [a, b] \big) = b-a
# $$
# This is only one of many useful probability distributions. We will learn about other distributions below.

# %% [markdown]
# ### Application: Compute π
#
#
#
# The area of the unit circle is $\pi$. If we draw two random numbers $x, y$, uniformly distributed in $[-1, 1]$ then the probability that the point $(x, y)$ belongs to the unit circle is exactly $\pi / 4$ (the area of the circle divided by the area of the square $[-1, 1]^2$.  Or, simpler, if we draw two random numbers $x, y$ uniformly distributed in $[0, 1]$ then the probability that $(x, y)$ belongs to the quarter unit circle is again $\pi/4$. Therefore, to compute $\pi$, we can simply draw many random numbers and compute the expectation that $(x,y)$ is in the quarter circle.
#
# <p><a href="https://commons.wikimedia.org/wiki/File:MonteCarloIntegrationCircle.svg#/media/File:MonteCarloIntegrationCircle.svg"><img width="300" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/20/MonteCarloIntegrationCircle.svg/1200px-MonteCarloIntegrationCircle.svg.png" alt="MonteCarloIntegrationCircle.svg"></a><br>By <a href="//commons.wikimedia.org/w/index.php?title=User:Yoderj&amp;action=edit&amp;redlink=1" class="new" title="User:Yoderj (page does not exist)">User:Yoderj</a>, <a href="https://en.wikipedia.org/wiki/User:Mysid" class="extiw" title="w:User:Mysid">Mysid</a> - <span class="int-own-work" lang="en">Own work</span>, derived in Inkscape from <a class="mw-selflink selflink">Image:MonteCarloIntegrationCircle.svg</a>, <a href="http://creativecommons.org/publicdomain/zero/1.0/deed.en" title="Creative Commons Zero, Public Domain Dedication">CC0</a>, <a href="https://commons.wikimedia.org/w/index.php?curid=35608043">Link</a></p>

# %%
# number of draws
Nsamples = 1_000_000  

# specify the function testing that two numbers are in the circle
# NOTE: True ≡ 1, False ≡ 0
incircle(x, y) = (x^2 + y^2 < 1)

count = 0
for n = 1:Nsamples 
    x, y = rand(), rand()
    count += incircle(x, y) 
end 
approx_pi = 4 * count / Nsamples 

println("Approximation for π: ", approx_pi)
println("Error: ", abs(π - approx_pi))
# Out:
# Approximation for π: 3.1426
# Error: 0.001007346410206722

# %% [markdown]
# The algorithm in the previous cell is in fact the simplest example of a Monte-Carlo Algorithm! See [Wikipedia](https://en.wikipedia.org/wiki/Monte_Carlo_method) for an introduction and for references.

# %% [markdown]
# Another very common distribution is the Gaussian, or Normal distribution $N(m, \sigma)$, given by
# $$
#     \mathbb{P}\big( x \in [a, b] \big) = \frac{1}{\sqrt{\pi}} \int_{a}^b e^{- (x-m)^2/\sigma} dx
# $$
# Here, $m$ is the mean and $\sigma$ the *variance* of the distribution. Informally, the variance measures how far random numbers are spread out from their average value; see [Wikipedia](https://en.wikipedia.org/wiki/Variance) for more information and references.
#
# The normal distribution can be visualised as $\mathbb{P}\big( x \in [a, b] \big)$ being the shaded area under the curve:

# %%
a, b = 0.5, 1.5
x = linspace(-3, 3, 200)
f(x) = π^(-1/2) * exp(- x^2)
plot(x, f.(x), lw=5, label = "", xlim=(-3.0, 3.0), ylim = (-0.05, 0.6))
x1 = linspace(a, b, 100)
plot!([x1[1];x1;x1[end];x1[1]], [0.0;f.(x1);0.0;0.0], lw=3, label="", fill=true,
        xticks = ([-3, 0, 0.5, 1.5, 3], 
                  ["-3", "0", "a=0.5", "b=1.5", "3"]), tickfont=font(13))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip8100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 42.5184,370.539 580.315,370.539 580.315,11.811 42.5184,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8102">
#     <rect x="42" y="11" width="539" height="360"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,370.539 42.5184,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   311.417,370.539 311.417,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   356.233,370.539 356.233,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   445.866,370.539 445.866,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.539 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,342.945 580.315,342.945
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,287.756 580.315,287.756
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,232.567 580.315,232.567
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,177.378 580.315,177.378
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,122.189 580.315,122.189
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5184,67 580.315,67
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,370.539 580.315,370.539
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,370.539 42.5184,11.811
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,370.539 42.5184,365.158
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   311.417,370.539 311.417,365.158
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   356.233,370.539 356.233,365.158
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   445.866,370.539 445.866,365.158
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,370.539 580.315,365.158
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,342.945 50.5854,342.945
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,287.756 50.5854,287.756
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,232.567 50.5854,232.567
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,177.378 50.5854,177.378
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,122.189 50.5854,122.189
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5184,67 50.5854,67
#   "/>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:middle;" transform="rotate(0, 42.5184, 390.339)" x="42.5184" y="390.339">-3</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:middle;" transform="rotate(0, 311.417, 390.339)" x="311.417" y="390.339">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:middle;" transform="rotate(0, 356.233, 390.339)" x="356.233" y="390.339">a=0.5</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:middle;" transform="rotate(0, 445.866, 390.339)" x="445.866" y="390.339">b=1.5</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:middle;" transform="rotate(0, 580.315, 390.339)" x="580.315" y="390.339">3</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:end;" transform="rotate(0, 36.5184, 349.945)" x="36.5184" y="349.945">0.0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:end;" transform="rotate(0, 36.5184, 294.756)" x="36.5184" y="294.756">0.1</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:end;" transform="rotate(0, 36.5184, 239.567)" x="36.5184" y="239.567">0.2</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:end;" transform="rotate(0, 36.5184, 184.378)" x="36.5184" y="184.378">0.3</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:end;" transform="rotate(0, 36.5184, 129.189)" x="36.5184" y="129.189">0.4</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:19; text-anchor:end;" transform="rotate(0, 36.5184, 74)" x="36.5184" y="74">0.5</text>
# </g>
# <polyline clip-path="url(#clip8102)" style="stroke:#009af9; stroke-width:5; stroke-opacity:1; fill:none" points="
#   42.5184,342.906 45.2209,342.899 47.9234,342.89 50.6259,342.879 53.3284,342.867 56.0309,342.852 58.7334,342.835 61.4359,342.814 64.1384,342.791 66.8409,342.763
#   69.5434,342.731 72.2458,342.693 74.9483,342.649 77.6508,342.599 80.3533,342.54 83.0558,342.473 85.7583,342.395 88.4608,342.305 91.1633,342.202 93.8658,342.084
#   96.5683,341.949 99.2708,341.796 101.973,341.621 104.676,341.422 107.378,341.196 110.081,340.94 112.783,340.652 115.486,340.326 118.188,339.96 120.891,339.549
#   123.593,339.088 126.296,338.572 128.998,337.997 131.701,337.356 134.403,336.643 137.106,335.852 139.808,334.977 142.511,334.01 145.213,332.944 147.916,331.771
#   150.618,330.483 153.321,329.072 156.023,327.529 158.726,325.846 161.428,324.013 164.131,322.022 166.8

# %% [markdown]
# More generally, if $f : \mathbb{R} \to \mathbb{R}_+$ with $\int_{\mathbb{R}} f(x) dx = 1$ then a probability distribution is defined by
# $$
#     \mathbb{P}(x \in [a, b]) = \int_a^b f(x) dx.
# $$
# Julia comes out of the box with
# * Uniform distribution: `rand`
# * Normal distribution: `randn`
# * exponential distribution: `randexp`

# %% [markdown]
# ### Application: Brownian Motion
#
# <p><a href="https://commons.wikimedia.org/wiki/File:Brownian_motion_large.gif#/media/File:Brownian_motion_large.gif"><img src="https://upload.wikimedia.org/wikipedia/commons/c/c2/Brownian_motion_large.gif" alt="Brownian motion large.gif" height="240" width="240"></a><br>By <a href="//commons.wikimedia.org/w/index.php?title=User:Lookang&amp;action=edit&amp;redlink=1" class="new" title="User:Lookang (page does not exist)">Lookang</a> Author of computer model: Francisco Esquembre, Fu-Kwun and lookang - <span class="int-own-work" lang="en">Own work</span>, <a href="https://creativecommons.org/licenses/by-sa/3.0" title="Creative Commons Attribution-Share Alike 3.0">CC BY-SA 3.0</a>, <a href="https://commons.wikimedia.org/w/index.php?curid=19140345">Link</a></p>
#
# The above video shows a large and heavy particle moving randomly by bouncing off many smaller surrounding particles, for example, Pollen grains in water (Brown) or small dust particles in air (Lucretius); see [Wikipedia](https://en.wikipedia.org/wiki/Brownian_motion) for a nice introduction. There are in fact a wide variety of physical scenarios where such random motion occurs naturally.
#
# Instead of accounting for every particle in the "bath", Einstein proposed to replace the "bath" with a random forcing term. We will not go into the mathematical or physical details of this *Brownian Motion* but instead simulate a time-discrete variant thereof:
# $$\begin{align*}
#     x_{n+1} &= x_n + \sqrt{\Delta t} R_n, \\
#     y_{n+1} &= y_n + \sqrt{\Delta t} S_n
# \end{align*}$$
# where $(x_n, y_n)$ are the position of the particle at time $n$ and
# $R_n, S_n \sim N(0, 1)$ are independent and normally distributed random samples.

# %%
Nsteps = 1_000
dt = 0.1
# allocate arrays 
x = zeros(Nsteps)
y = zeros(Nsteps)
# simulate the RW 
for n = 2:Nsteps 
    a, b = rand()-0.5, rand() - 0.5
    x[n] = x[n-1] + sqrt(dt) * a 
    y[n] = y[n-1] + sqrt(dt) * b 
end

# %%
# and animation of the random walk
@gif for n = 1:10:Nsteps
    plot(x[1:n], y[1:n], xlim = (-6, 6), ylim = (-6, 6), label="")
    plot!([x[n]], [y[n]], lw=0, marker=:o, ms=8, label = "")
end
# Out:
# INFO: Saved animation to /Users/ortner/gits/InterdisciplinaryComputing/L3/tmp.gif
# Plots.AnimatedGif("/Users/ortner/gits/InterdisciplinaryComputing/L3/tmp.gif")

# %%
# or a completely different interpretation? 
t = linspace(0, 365, Nsteps)
plot(t, x, label="")
plot!(t, y, label="", 
      xticks = (cumsum([31, 30, 31, 28, 31, 30, 31, 31, 30, 31, 30, 31]), 
                ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                 "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]) )
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip8300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8302">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   76.0611,375.813 76.0611,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.353,375.813 121.353,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   168.155,375.813 168.155,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   210.428,375.813 210.428,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   257.23,375.813 257.23,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   302.522,375.813 302.522,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   349.324,375.813 349.324,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   396.126,375.813 396.126,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   441.419,375.813 441.419,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   488.221,375.813 488.221,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   533.513,375.813 533.513,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.813 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,372.619 580.315,372.619
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,320.485 580.315,320.485
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,268.352 580.315,268.352
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,216.218 580.315,216.218
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,164.084 580.315,164.084
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,111.95 580.315,111.95
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.2591,59.8162 580.315,59.8162
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.0611,375.813 76.0611,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.353,375.813 121.353,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   168.155,375.813 168.155,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   210.428,375.813 210.428,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   257.23,375.813 257.23,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   302.522,375.813 302.522,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   349.324,375.813 349.324,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   396.126,375.813 396.126,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   441.419,375.813 441.419,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   488.221,375.813 488.221,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   533.513,375.813 533.513,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,372.619 37.525,372.619
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,320.485 37.525,320.485
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,268.352 37.525,268.352
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,216.218 37.525,216.218
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,164.084 37.525,164.084
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,111.95 37.525,111.95
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,59.8162 37.525,59.8162
#   "/>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 76.0611, 389.613)" x="76.0611" y="389.613">Jan</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 121.353, 389.613)" x="121.353" y="389.613">Feb</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 168.155, 389.613)" x="168.155" y="389.613">Mar</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 210.428, 389.613)" x="210.428" y="389.613">Apr</text>
# </g>
# <g clip-path="url(#clip8300)">
# <t

# %% [markdown]
# ### Other Distributions
#
# Many distributions can be generated from `rand`, `randn` and `randexp`, however it is in general a subtle problem to implement new distributions in an efficient and numerically robust way. A better approach is to find a library that already has the needed distributions implemented: `Distributions.jl`

# %%
using Distributions

# %%
?Distributions
# Out:
# search: Distributions Distribution MatrixDistribution NonMatrixDistribution
# A Julia package for probability distributions and associated functions.
#
# API overview (major features):
#
#   * `d = Dist(parameters...)` creates a distribution instance `d` for some distribution `Dist` (see choices below) with the specified `parameters`
#   * `rand(d, sz)` samples from the distribution
#   * `pdf(d, x)` and `logpdf(d, x)` compute the probability density or log-probability density of `d` at `x`
#   * `cdf(d, x)` and `ccdf(d, x)` compute the (complementary) cumulative distribution function at `x`
#   * `quantile(d, p)` is the inverse `cdf` (see also `cquantile`)
#   * `mean(d)`, `var(d)`, `std(d)`, `skewness(d)`, `kurtosis(d)` compute moments of `d`
#   * `fit(Dist, xs)` generates a distribution of type `Dist` that best fits the samples in `xs`
#
# These represent just a few of the operations supported by this package; users are encouraged to refer to the full documentation at http://distributionsjl.readthedocs.org/en/latest/ for further information.
#
# Supported distributions:
#
# ```
# Arcsine, Bernoulli, Beta, BetaBinomial, BetaPrime, Binomial, Biweight,
# Categorical, Cauchy, Chi, Chisq, Cosine, DiagNormal, DiagNormalCanon,
# Dirichlet, DiscreteUniform, DoubleExponential, EdgeworthMean,
# EdgeworthSum, EdgeworthZ, EmpiricalUnivariateDistribution, Erlang,
# Epanechnikov, Exponential, FDist, FisherNoncentralHypergeometric,
# Frechet, FullNormal, FullNormalCanon, Gamma, GeneralizedPareto,
# GeneralizedExtremeValue, Geometric, Gumbel, Hypergeometric,
# InverseWishart, InverseGamma, InverseGaussian, IsoNormal,
# IsoNormalCanon, Kolmogorov, KSDist, KSOneSided, Laplace, Levy,
# Logistic, LogNormal, MixtureModel, Multinomial, MultivariateNormal,
# MvLogNormal, MvNormal, MvNormalCanon, MvNormalKnownCov, MvTDist,
# NegativeBinomial, NoncentralBeta, NoncentralChisq, NoncentralF,
# NoncentralHypergeometric, NoncentralT, Normal, NormalCanon,
# NormalInverseGaussian, Pareto, Poisson, PoissonBinomial,
# QQPair, Rayleigh, Skellam, SymTriangularDist, TDist, TriangularDist,
# Triweight, Truncated, TruncatedNormal, Uniform, UnivariateGMM,
# VonMises, VonMisesFisher, WalleniusNoncentralHypergeometric, Weibull,
# Wishart, ZeroMeanIsoNormal, ZeroMeanIsoNormalCanon,
# ZeroMeanDiagNormal, ZeroMeanDiagNormalCanon, ZeroMeanFullNormal,
# ZeroMeanFullNormalCanon
# ```

# %% [markdown]
# ### Application: speed of Maxwell particles
#
# Suppose a particle has velocity vector $\mathbf{v} = (v_1, v_2, v_3)$ with $v_j \sim N(\bar{v}, 1)$ and independently distributed (Maxwell distribution). Then the *speed* of the particle is distributed according to the [Chi Distribution](https://en.wikipedia.org/wiki/Chi_distribution):
# $$
#     v = |\mathbf{v}| = \sqrt{v_1^2 + v_2^2 + v_3^2}
# $$

# %%
?Chi
# Out:
# search: Chi Chisq eachindex searchindex rsearchindex eachline EachLine chr2ind
# ```
# Chi(ν)
# ```
#
# The *Chi distribution* `ν` degrees of freedom has probability density function
#
# $$
# f(x; k) = \frac{1}{\Gamma(k/2)} 2^{1 - k/2} x^{k-1} e^{-x^2/2}, \quad x > 0
# $$
#
# It is the distribution of the square-root of a [`Chisq`](@ref) variate.
#
# ```julia
# Chi(k)       # Chi distribution with k degrees of freedom
#
# params(d)    # Get the parameters, i.e. (k,)
# dof(d)       # Get the degrees of freedom, i.e. k
# ```
#
# External links
#
#   * [Chi distribution on Wikipedia](http://en.wikipedia.org/wiki/Chi_distribution)

# %%
@show D = Chi(3)
@show mean(D)
@show var(D)     # variance 
;
# Out:
# D = Chi(3) = Distributions.Chi{Float64}(ν=3.0)
# mean(D) = 1.5957691216057308
# var(D) = 0.45352091052967447

# %% [markdown]
# For fun, we can perform a simple test that this is indeed the correct distribution, by creating samples of gaussian random vectors and putting their lengths into bins.

# %%
Nsamples = 1_000_000
# generate random speeds
v = [ norm(randn(3))  for n = 1:Nsamples ]
# Categorize into bins and plot the bins
histogram(v, nbins = 100, normed=true, label = "empirical")
# plot the probability density function on top 
x = linspace(0, 5, 100)
plot!(x, pdf.(D, x), lw=3, label="theoretical")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip8500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8502">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.7342,375.813 47.7342,11.811
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   138.448,375.813 138.448,11.811
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   229.162,375.813 229.162,11.811
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   319.876,375.813 319.876,11.811
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   410.589,375.813 410.589,11.811
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   501.303,375.813 501.303,11.811
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,313.98 580.315,313.98
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,252.146 580.315,252.146
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,190.312 580.315,190.312
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,128.479 580.315,128.479
#   "/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,66.6451 580.315,66.6451
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,375.813 47.7342,370.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   138.448,375.813 138.448,370.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   229.162,375.813 229.162,370.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   319.876,375.813 319.876,370.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   410.589,375.813 410.589,370.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   501.303,375.813 501.303,370.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 40.4435,375.813
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,313.98 40.4435,313.98
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,252.146 40.4435,252.146
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,190.312 40.4435,190.312
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,128.479 40.4435,128.479
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,66.6451 40.4435,66.6451
#   "/>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 47.7342, 389.613)" x="47.7342" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 138.448, 389.613)" x="138.448" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 229.162, 389.613)" x="229.162" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 319.876, 389.613)" x="319.876" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 410.589, 389.613)" x="410.589" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 501.303, 389.613)" x="501.303" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 380.313)" x="26.2221" y="380.313">0.0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 318.48)" x="26.2221" y="318.48">0.1</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 256.646)" x="26.2221" y="256.646">0.2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 194.812)" x="26.2221" y="194.812">0.3</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 132.979)" x="26.2221" y="132.979">0.4</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 71.1451)" x="26.2221" y="71.1451">0.5</text>
# </g>
# <polygon clip-path="url(#clip8502)" points="
# 47.7342,374.243 47.7342,375.813 56.8055,375.813 56.8055,374.243 47.7342,374.243 47.7342,374.243
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip8502)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="

# %% [markdown]
# ### Fitting a distribution
#
# Suppose that we have some random (or, noisy) data, which we *believe* corresponds to a certain distribution but we don't know the correct parameters. Then `Distributions.jl` has a mechanism of determining the parameters for you: [Distribution Fitting](https://juliastats.github.io/Distributions.jl/latest/fit.html#Distribution-Fitting-1), implemented using [Maximum Likelihood estimation](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation). We will not cover this method, but only use it.

# %%
?fit
# Out:
# search: fit fit_mle fit_map fit_mle! fit_map! filt filt! filter filter! first
# ```
# fit(Histogram, data[, weight][, edges]; closed=:right, nbins)
# ```
#
# Fit a histogram to `data`.
#
# # Arguments
#
#   * `data`: either a vector (for a 1-dimensional histogram), or a tuple of vectors of equal length (for an *n*-dimensional histogram).
#   * `weight`: an optional `AbstractWeights` (of the same length as the data vectors), denoting the weight each observation contributes to the bin. If no weight vector is supplied, each observation has weight 1.
#   * `edges`: a vector (typically an `AbstractRange` object), or tuple of vectors, that gives the edges of the bins along each dimension. If no edges are provided, these are determined from the data.
#
# # Keyword arguments
#
#   * `closed=:right`: if `:left`, the bin intervals are left-closed [a,b); if `:right` (the default), intervals are right-closed (a,b].
#   * `nbins`: if no `edges` argument is supplied, the approximate number of bins to use along each dimension (can be either a single integer, or a tuple of integers).
#
# # Examples
#
# ```julia
# # Univariate
# h = fit(Histogram, rand(100))
# h = fit(Histogram, rand(100), 0:0.1:1.0)
# h = fit(Histogram, rand(100), nbins=10)
# h = fit(Histogram, rand(100), weights(rand(100)), 0:0.1:1.0)
# h = fit(Histogram, [20], 0:20:100)
# h = fit(Histogram, [20], 0:20:100, closed=:left)
#
# # Multivariate
# h = fit(Histogram, (rand(100),rand(100)))
# h = fit(Histogram, (rand(100),rand(100)),nbins=10)
# ```
#
# Fit a statistical model.

# %% [markdown]
# **Warning:** Unfortunately, `fit` is not implemented for all distributions, e.g., it is not available for the $\chi$-distribution.

# %%
Nsamples = 1_000_000
v = [ norm(randn(3))  for n = 1:Nsamples ]
D = fit(Chi, v)
# Out:
# suffstats is not implemented for (Distributions.Chi, Array{Float64,1}).
#
# Stacktrace:
#  [1] suffstats(::Type{Distributions.Chi}, ::Array{Float64,1}) at /Users/ortner/.julia/v0.6/Distributions/src/genericfit.jl:5
#  [2] fit(::Type{Distributions.Chi}, ::Array{Float64,1}) at /Users/ortner/.julia/v0.6/Distributions/src/genericfit.jl:33
#  [3] include_string(::String, ::String) at ./loading.jl:522

# %% [markdown]
# However, the $\chi^2$ fit is implemented, in that the $\chi^2$-distribution is a special case of the $\Gamma$-distribution.

# %%
# create many random samples
Nsamples = 1_000_000
v = [ norm(randn(3))^2  for n = 1:Nsamples ]   
# fit the data `v` to the Γ distribution 
D = fit(Gamma, v)
# Out:
# Distributions.Gamma{Float64}(α=1.4997654668313314, θ=1.9999475942742404)

# %%
# Visualise the result to make sure the fit is ok!
# Categorize data into bins and plot the height of the bins
histogram(v, nbins = 100, normed=true, label = "empirical")
# plot the probability density function on top 
x = linspace(0, 20, 200)
plot!(x, pdf.(D, x), lw=3, label="fit to Gamma", xlim=(-2, 22), ylim = (0,0.25))

# # REMARK: if we naively fit to a normal (e.g.) then this 
# #         is of course admissible but the fit will be poor!
# Dn = fit(Normal, v)
# xn = linspace(-2, 15, 200)
# plot!(x, pdf.(Dn, x), lw=3, ls = :dot, label="fit to Normal", color = :black)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9100)" points="
# 38.8117,375.813 580.315,375.813 580.315,11.811 38.8117,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9102">
#     <rect x="38" y="11" width="543" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   83.937,375.813 83.937,11.811
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   196.75,375.813 196.75,11.811
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.563,375.813 309.563,11.811
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   422.377,375.813 422.377,11.811
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   535.19,375.813 535.19,11.811
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,303.013 580.315,303.013
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,230.212 580.315,230.212
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,157.412 580.315,157.412
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,84.6115 580.315,84.6115
#   "/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.8117,11.811 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 38.8117,11.811
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   83.937,375.813 83.937,370.353
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.75,375.813 196.75,370.353
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.563,375.813 309.563,370.353
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   422.377,375.813 422.377,370.353
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   535.19,375.813 535.19,370.353
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 46.9343,375.813
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,303.013 46.9343,303.013
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,230.212 46.9343,230.212
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,157.412 46.9343,157.412
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,84.6115 46.9343,84.6115
#   "/>
# <polyline clip-path="url(#clip9100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,11.811 46.9343,11.811
#   "/>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 83.937, 389.613)" x="83.937" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 196.75, 389.613)" x="196.75" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.563, 389.613)" x="309.563" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 422.377, 389.613)" x="422.377" y="389.613">15</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 535.19, 389.613)" x="535.19" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 380.313)" x="32.8117" y="380.313">0.00</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 307.513)" x="32.8117" y="307.513">0.05</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 234.712)" x="32.8117" y="234.712">0.10</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 161.912)" x="32.8117" y="161.912">0.15</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 89.1115)" x="32.8117" y="89.1115">0.20</text>
# </g>
# <g clip-path="url(#clip9100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 16.311)" x="32.8117" y="16.311">0.25</text>
# </g>
# <polygon clip-path="url(#clip9102)" points="
# 83.937,140.051 83.937,375.813 95.2183,375.813 95.2183,140.051 83.937,140.051 83.937,140.051
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   83.937,140.051 83.937,375.813 95.2183,375.813 95.2183,140.051 83.937,140.051
#   "/>
# <polygon clip-path="url(#clip9102)" points="
# 95.2183,30.7916 95.2183,375.813 106.5,375.813 106.5,30.7916 95.2183,30.7916 95.2183,30.7916
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip9102)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   95.2183,30.7916 95.2183,375.813 106.5,375.813 106.5,30.7916 95.2183,30.7916
#   "/>
# <polygon clip-path="url(#clip9102)" points="
# 106.5,29.554 106.5,375.813 117.781,375.813 117.781,29.554 106.

# %% [markdown]
# ### Remark on Random Number Generators
#
# A word of warning: a computer cannot generate *genuine* random numbers, instead it generates so-called pseudo-random numbers. They look (and for most practical purposes act) like real random numbers, but there are some limitations. For more on RNGs see [Wikipedia](https://en.wikipedia.org/wiki/Random_number_generation) and for more in RNGs in Julia see [the documentation](https://docs.julialang.org/en/stable/stdlib/numbers/#Random-Numbers-1)
#
# Look in particular at the documentation for `srand` in order to understand how to "seed" (i.e initialise) random number generators.

# %%
?srand
# Out:
# search: srand sprand sprandn @shorthands AbstractBackend SymTriangularDist
# ```
# srand([rng=GLOBAL_RNG], [seed]) -> rng
# srand([rng=GLOBAL_RNG], filename, n=4) -> rng
# ```
#
# Reseed the random number generator. If a `seed` is provided, the RNG will give a reproducible sequence of numbers, otherwise Julia will get entropy from the system. For `MersenneTwister`, the `seed` may be a non-negative integer, a vector of [`UInt32`](@ref) integers or a filename, in which case the seed is read from a file (`4n` bytes are read from the file, where `n` is an optional argument). `RandomDevice` does not support seeding.
